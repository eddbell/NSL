# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 3</span>

# %% [markdown]
# ### For comparison, Black-Scholes analytic solution:

# %%
import scipy
from scipy.special import erf
import numpy
from numpy import exp
from numpy.lib.scimath import log, sqrt

# data
S0 = 100.
K = 100.
T = 1.
r = 0.1
sigma = 0.25
t=0

def N(x):
    return 0.5 * (1. + erf(x / sqrt(2.)))

def black_scholes(S0, K, T, r, sigma):
    d1 = 1./(sigma * sqrt(T)) * (ddlog(S0 / K) + (r + (sigma**2) / 2.) * T)
    d2 = d1 - sigma * sqrt(T)
    C = S0 * N(d1) - K * exp(-r * T) * N(d2)
    P = S0 *(N(d1) - 1.) - K * exp(-r * T) * (N(d2)-1.)
    return C, P

if __name__ == "__main__":
    call, put = black_scholes(S0, K, T, r, sigma)
    print(" == BLACK-SCHOLES ==")
    print("call: ", call)
    print("put: ", put)
# Out:
#  == BLACK-SCHOLES ==
# call:  14.975790778311286
# put:  5.4595325819072364

# %%
#Definisco alcune variabili
teo_call = np.ones(100)*call
teo_put = np.ones(100)*put
M=100000
N=100

x = np.arange(100)*M/N

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


call_sum, call_err = np.loadtxt("../dati/dati3/dati3.1.1.dat", usecols=(0,1), delimiter=',', unpack='true')
put_sum, put_err = np.loadtxt("../dati/dati3/dati3.1.2.dat", usecols=(0,1), delimiter=',', unpack='true')


plt.errorbar(x,call_sum-teo_call,yerr=call_err)
plt.errorbar(x,put_sum-teo_put,yerr=put_err)
plt.xlabel('#throws')
plt.ylabel('<r>')
plt.grid(True)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

call_sum, call_err = np.loadtxt("../dati/dati3/dati3.2.1.dat", usecols=(0,1), delimiter=',', unpack='true')
put_sum, put_err = np.loadtxt("../dati/dati3/dati3.2.2.dat", usecols=(0,1), delimiter=',', unpack='true')

plt.errorbar(x,call_sum-teo_call,yerr=call_err)
plt.errorbar(x,put_sum-teo_put,yerr=put_err)
plt.xlabel('#throws')
plt.ylabel('<r>')
plt.legend()
plt.grid(False)
plt.show()
# Out:
# No handles with labels found to put in legend.
