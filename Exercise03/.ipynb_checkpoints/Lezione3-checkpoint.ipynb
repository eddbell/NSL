# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 3</span>

# %% [markdown]
# ### For comparison, Black-Scholes analytic solution:

# %%
import scipy
from scipy.special import erf
import numpy as np
from numpy import exp
from numpy.lib.scimath import log, sqrt
import matplotlib
import matplotlib.pyplot as plt


# data
S0 = 100.
K = 100.
T = 1.
r = 0.1
sigma = 0.25
t=0

def N(x):
    return 0.5 * (1. + erf(x / sqrt(2.)))

def black_scholes(S0, K, T, r, sigma):
    d1 = 1./(sigma * sqrt(T)) * (log(S0 / K) + (r + (sigma**2) / 2.) * T)
    d2 = d1 - sigma * sqrt(T)
    C = S0 * N(d1) - K * exp(-r * T) * N(d2)
    P = S0 *(N(d1) - 1.) - K * exp(-r * T) * (N(d2)-1.)
    return C, P

if __name__ == "__main__":
    call, put = black_scholes(S0, K, T, r, sigma)
    print(" == BLACK-SCHOLES ==")
    print("call: ", call)
    print("put: ", put)
# Out:
#  == BLACK-SCHOLES ==
# call:  14.975790778311286
# put:  5.4595325819072364

# %%
#Definisco alcune variabili
M=100000
N=100
x = np.arange(100)*M/N

# %%
call_sum, call_err = np.loadtxt("./data/call1.dat", usecols=(0,1), delimiter=',', unpack='true')
put_sum, put_err = np.loadtxt("./data/put1.dat", usecols=(0,1), delimiter=',', unpack='true')

plt.figure(figsize=(12,8))
plt.errorbar(x,call_sum,yerr=call_err,label="CALL simulations")
plt.hlines(call,0,x[-1], label ="CALL theory", color = "blue")
plt.errorbar(x,put_sum,yerr=put_err,label="PUT simulations")
plt.hlines(put,0,x[-1], label ="PUT theory", color = "red")
plt.xlabel('#throws')
plt.ylabel('Blocks average')
plt.legend()
plt.grid(True)
plt.show()

# %%
call_sum, call_err = np.loadtxt("./data/call2.dat", usecols=(0,1), delimiter=',', unpack='true')
put_sum, put_err = np.loadtxt("./data/put2.dat", usecols=(0,1), delimiter=',', unpack='true')

plt.figure(figsize=(12,8))
plt.errorbar(x,call_sum,yerr=call_err,label="CALL simulations")
plt.hlines(call,0,x[-1], label ="CALL theory", color = "blue")
plt.errorbar(x,put_sum,yerr=put_err,label="PUT simulations")
plt.hlines(put,0,x[-1], label ="PUT theory", color = "red")
plt.xlabel('#throws')
plt.ylabel('Blocks average')
plt.legend()
plt.grid(True)
plt.show()
