# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import os
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD, Adam, Adadelta
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

import matplotlib.style as style 
style.use('tableau-colorblind10')
# Out:
# 2022-07-01 13:40:15.786512: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-01 13:40:15.786548: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# The goal of this exercises is to perform ML regression on noisy data usign a feedforward neural network (NN).
#
# The universal approximation theorem guarantees that Neural Networks can transform (non linearly) the input $X$ into an output $Y$ that depends on the weights and biases of all the neurons in the network, whatever it is the form of the function that links $X$ to $Y$.
#
# We will be using a [Sequential model](https://keras.io/guides/sequential_model/) to model the layers of our network.
#
# We will takle the **prediction problem**: given a probabilistic process that outputs labeled data $(x,y)$, with $y_i = f(x_i)+\eta_i$, $\eta_i$ gaussian and uncorrelated noise such that: $\langle \eta_i \rangle=0$ and $\langle \eta_i \eta_j \rangle=\delta_{ij}\sigma$, the output of our neural network will provide us with a set of prediction $\{ y_j^{\text{pred}} \}$. To measure the goodness of our hypothesis we measure on the test set the sum of the mean square error (MSE).
#
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$

# %% [markdown]
# # Exercise 11.1
# ### Linear regression

# %% [markdown]
# Our first steps should be easy ones, so in this exercise we have a dataset distributed following:
#
# $$
# f(x) = 2x +1.
# $$
#
# In this case a network of a single layer and a single neuron is enough to tackle the problem.
#
# The only parameters to be optimized will be the weights $w_j$ and the biases $b_j$. At first the parameters we will use are: $N_{\text{train}}=100$ and $N_{\text{valid}}=10$ (our test values, in this case directly sampled from the analytical model). Our network will be trained using **30 epochs**, the noise is $\sigma=0$. We explore how changing this values will impact the predictive power of our model.

# %% [markdown]
# As a first thing, we generate and plot a set of input data that will be used as training set and test set.

# %%
def generate_input(n_train,m,b,sigma):
    # generate training inputs
    n_valid = int(n_train/10)
    np.random.seed(0)
    x_train = np.random.uniform(-1, 1, n_train)
    x_valid = np.random.uniform(-1, 1, n_valid)
    x_valid.sort()
    y_target = m * x_valid + b # ideal (target) linear function

    y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
    y_valid = np.random.normal(m * x_valid + b, sigma)
    return x_train, x_valid, y_target ,y_train, y_valid

def Set_model(n_node):
    # compose the NN model
    model = tf.keras.Sequential()
    model.add(Dense(n_node, input_shape=(1,)))#let add just one layer and one node.

    # compile the model choosing optimizer, loss and metrics objects
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

    # get a summary of our composed model
    model.summary()
    
    # save the weights that we will use later
    model.save_weights('model.h5')
    return model
    
def Test(n_epochs):
    #test my model
    history = model.fit(x=x_train, y=y_train, 
            batch_size=32, epochs=n_epochs,
            shuffle=True, # a good idea is to shuffle input before at each epoch
            validation_data=(x_valid, y_valid),
            verbose = 0)
    return history;

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
def plot_model(): 
    par = model.get_weights()

    #print('\n\n------------------------------------------------------\n')
    #print('The model function obtained is: \n\nf(x) = '+ str(float(par[0]))+'x + ' +str(float(par[1])))
    #print('\n\n------------------------------------------------------')

    # look into training history
    # Plot training & validation loss values
    plt. subplots(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss', fontsize=16)
    plt.grid()
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Validation'], loc='best')

    # Plot target and fit
    plt.subplot(1,2,2)
    plt.title('Target function and predicted function', fontsize=16)
    x_predicted = np.random.uniform(-1, 1, 100)
    y_predicted = model.predict(x_predicted)
    # Fitted function
    plt.plot(x_predicted, y_predicted,'ro', label='predicted')
    # Target function
    plt.plot(x_valid, y_target, label='target')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_perf(model, y_target, x_valid, y_valid):
    print('\n\n------------------------------------------------------\n')
    # evaluate model
    score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

    # print performance
    print()
    print('Evaluation of the model by comparison with the exact curve:')
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

    print('\n\n------------------------------------------------------')

# %%
#TEST 1
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect
sigma = 0.0 # noise standard deviation, for the moment it is absent
n_train = 300
n_epochs = 30
n_node = 1
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#setting model
model = Set_model(n_node)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# 2022-06-30 19:07:12.197808: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-30 19:07:12.197846: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-30 19:07:12.197869: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (edd-VivoBook-ASUSLaptop-X521IA-M533IA): /proc/driver/nvidia/version does not exist
# 2022-06-30 19:07:12.198155: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0581 - mse: 0.0581
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.058137696236371994
# Test accuracy: 0.058137696236371994
#
#
# ------------------------------------------------------

# %% [markdown]
# **OBSERVATION**
#
#
# First we ran the model with 300 trains, using 10% of trains are used to validate the test, and 30 epochs
#
# Left plot show that to improve results is enough to increase the number of epochs.
# Actually the mean square error trend tend toward zero.

# %% [markdown]
# **Test 2**: **increase the number of epochs from 30 to 100**

# %%
#TEST 2
n_train = 300
n_epochs = 100

#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 22ms/step - loss: 4.6348e-06 - mse: 4.6348e-06
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 4.634793185687158e-06
# Test accuracy: 4.634793185687158e-06
#
#
# ------------------------------------------------------

# %% [markdown]
# ### OBSERVATION
#
# ccuracy has improved appreciably.
#
# We now test the model by increasing the number of throws and leaving the number of epochs unchanged.

# %%
#TEST 3
n_train = 1000
n_epochs = 30

#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 4/4 [==============================] - 0s 3ms/step - loss: 8.2607e-06 - mse: 8.2607e-06
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 8.260716640506871e-06
# Test accuracy: 8.260716640506871e-06
#
#
# ------------------------------------------------------

# %% [markdown]
# ### OBSERVATION
#
# Matching loss tests one could observe that **more training is better than more epochs**.
# Actually larger training set provides loss values much smaller than those previously obtained. Now the loss function coverges to zero after 10 epochs going 3ms/step, while previusly the loss function coverges to zero after 40 epochs going 22ms/step.

# %%
#TEST 4
n_train = 1000
n_epochs = 100
sigma = 0.5
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 4/4 [==============================] - 0s 2ms/step - loss: 6.2376e-05 - mse: 6.2376e-05
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 6.237581692403182e-05
# Test accuracy: 6.237581692403182e-05
#
#
# ------------------------------------------------------

# %% [markdown]
# Obviusly introducing a noise in dataset generator lead to worse results. In addiction one could observe the loss curve got a gap between validation values. This gap show us we are not overstiming the results.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
def polynomial(x):
    return 4-3*x-2*x*x+3*x*x*x

def generate_input(n_train):
    # generate training inputs
    n_valid = 100
    np.random.seed(0)
    x_train = np.random.uniform(-1, 1, n_train)
    x_valid = np.random.uniform(-1, 1, n_valid)
    x_valid.sort()
    
    y_target = polynomial(x_valid) # ideal (target) linear function
    y_valid = np.random.normal(polynomial(x_valid))

    y_train = np.random.normal(polynomial(x_train)) # actual measures from which we want to guess regression parameters

    return x_train, x_valid, y_target ,y_train, y_valid

#define models
def Set_model(n_layer, n_node,activation):
    
    # compose the model with more nodes
    Nod_mod = tf.keras.Sequential()
    Nod_mod.add(Dense(1, input_shape=(1,),activation=activation))
    Nod_mod.add(Dense(n_node, input_shape=(1,),activation=activation))
    Nod_mod.add(Dense(1, input_shape=(1,),activation=activation))
    
    # compose the model with more layer
    Lay_mod = tf.keras.Sequential()
    for i in range(n_layer): Lay_mod.add(Dense(1, input_shape=(1,),activation=activation))

    # compose the model with more layer & more nodes
    Mix_mod = tf.keras.Sequential()
    Mix_mod.add(Dense(1, input_shape=(1,),activation=activation))
    for i in range(3): Mix_mod.add(Dense(2+i, input_shape=(1,),activation=activation))
    for i in range(3): Mix_mod.add(Dense(3-i, input_shape=(1,),activation=activation))
    Mix_mod.add(Dense(1, input_shape=(1,),activation=activation))

    return [Nod_mod, Lay_mod, Mix_mod]

def Compile(models, opt,loss,met,mod_names):
    i=0
    for model in models:
        model.compile(optimizer=opt, loss=loss, metrics=[met])
        model.summary(); print()
        i=i+1
    
def History(models,n_epochs,mod_names): #training model with history database
    #load weights
    j=0
    history = []
    for model in models: 
        history.append(model.fit(x = x_train, y = y_train, 
          batch_size=150, epochs=n_epochs, shuffle=True,
          validation_data=(x_valid, y_valid), verbose=1))
        j=j+1
    return history

# %%
n_train = 10000
n_epochs = 30
n_layer = 10
n_node = 15
mod_names = ["MORE NODE","MORE LAYER","MORE NODE & LAYER"]
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,sigma)

#setting model
models = Set_model(n_layer, n_node, "selu")

#compiling
Compile(models, SGD(),'loss','mse',mod_names)

#starting model
history = History(models,n_epochs,mod_names)
# Out:
# Model: "sequential_200"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1305 (Dense)          (None, 15)                30
#
#  dense_1306 (Dense)          (None, 1)                 16
#
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_201"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1307 (Dense)          (None, 1)                 2
#
#  dense_1308 (Dense)          (None, 1)                 2
#
#  dense_1309 (Dense)          (None, 1)                 2
#
#  dense_1310 (Dense)          (None, 1)                 2
#
#  dense_1311 (Dense)          (None, 1)                 2
#
#  dense_1312 (Dense)          (None, 1)                 2
#
#  dense_1313 (Dense)          (None, 1)                 2
#
#  dense_1314 (Dense)          (None, 1)                 2
#
#  dense_1315 (Dense)          (None, 1)                 2
#
#  dense_1316 (Dense)          (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_202"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1317 (Dense)          (None, 1)                 2
#
#  dense_1318 (Dense)          (None, 2)                 4
#
#  dense_1319 (Dense)          (None, 3)                 9
#
#  dense_1320 (Dense)          (None, 4)                 16
#
#  dense_1321 (Dense)          (None, 3)                 15
#
#  dense_1322 (Dense)          (None, 2)                 8
#
#  dense_1323 (Dense)          (None, 1)                 3
#
#  dense_1324 (Dense)          (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4026/2958695053.py in <module>
#      15
#      16 #starting model
# ---> 17 history = History(models,n_epochs,mod_names)
#
# /tmp/ipykernel_4026/433816121.py in History(models, n_epochs, mod_names)
#      50     history = []
#      51     for model in models:
# ---> 52         history.append(model.fit(x = x_train, y = y_train,
#      53           batch_size=150, epochs=n_epochs, shuffle=True,
#      54           validation_data=(x_valid, y_valid), verbose=1))
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 890, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/training.py", line 948, in compute_loss
#         return self.compiled_loss(
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/compile_utils.py", line 184, in __call__
#         self.build(y_pred)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/compile_utils.py", line 133, in build
#         self._losses = tf.nest.map_structure(self._get_loss_object, self._losses)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/engine/compile_utils.py", line 272, in _get_loss_object
#         loss = losses_mod.get(loss)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/losses.py", line 2367, in get
#         return deserialize(identifier)
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/losses.py", line 2322, in deserialize
#         return deserialize_keras_object(
#     File "/home/edd/anaconda3/lib/python3.9/site-packages/keras/utils/generic_utils.py", line 709, in deserialize_keras_object
#         raise ValueError(
#
#     ValueError: Unknown loss function: loss. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
def plot_models(models):
    i=0
    for model in models:
        print(f'{mod_names[i]}')
        plot_perf(model, y_target, x_valid, y_valid)

        # look into training history
        # Plot training & validation loss values
        plt. subplots(figsize=(15,5))
        plt.subplot(1,2,1)
        plt.plot(history[i].history['loss'])
        plt.plot(history[i].history['val_loss'])
        plt.title('Model loss', fontsize=16)
        plt.grid()
        plt.ylabel('Loss')
        plt.xlabel('Epochs')
        plt.legend(['Train', 'Validation'], loc='best')

        # Plot target and fit
        plt.subplot(1,2,2)
        plt.title('Target function and predicted function', fontsize=16)
        x_predicted = np.random.uniform(-1, 1, 100)
        y_predicted = model.predict(x_predicted)
        # Fitted function
        plt.plot(x_predicted, y_predicted,'ro', label='predicted')
        # Target function
        plt.plot(x_valid, y_target, label='target')
        plt.legend()
        plt.grid(True)
        plt.show()
        i=i+1
plot_models(models)
# Out:
# MORE NODE
#
#
# ------------------------------------------------------
#
# 32/32 [==============================] - 0s 3ms/step - loss: 8.2533e-04 - mse: 8.2533e-04
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.0008253274136222899
# Test accuracy: 0.0008253274136222899
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 3ms/step
# MORE LAYER
#
#
# ------------------------------------------------------
#
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2718 - mse: 0.2718
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.27179205417633057
# Test accuracy: 0.27179205417633057
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 3ms/step
# MORE NODE & LAYER
#
#
# ------------------------------------------------------
#
# 32/32 [==============================] - 0s 3ms/step - loss: 2.0568e-04 - mse: 2.0568e-04
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.00020567511091940105
# Test accuracy: 0.00020567511091940105
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# provo diverse funzioni di attivazioni: ELU

# %%
activations =["selu","relu","gelu","sigmoid","softmax","linear"]
multimodels = []
multihistory = []
for activation in activations:
    #setting model
    multimodels.append(Set_model(n_layer, n_node, activation))

    #compiling
    Compile(models, SGD(),'mse','mse',mod_names)

    #starting model
    multihistory.append(History(models,n_epochs,mod_names))
# Out:
# Model: "sequential_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_903 (Dense)           (None, 15)                30
#
#  dense_904 (Dense)           (None, 1)                 16
#
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_905 (Dense)           (None, 1)                 2
#
#  dense_906 (Dense)           (None, 1)                 2
#
#  dense_907 (Dense)           (None, 1)                 2
#
#  dense_908 (Dense)           (None, 1)                 2
#
#  dense_909 (Dense)           (None, 1)                 2
#
#  dense_910 (Dense)           (None, 1)                 2
#
#  dense_911 (Dense)           (None, 1)                 2
#
#  dense_912 (Dense)           (None, 1)                 2
#
#  dense_913 (Dense)           (None, 1)                 2
#
#  dense_914 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_915 (Dense)           (None, 1)                 2
#
#  dense_916 (Dense)           (None, 2)                 4
#
#  dense_917 (Dense)           (None, 3)                 9
#
#  dense_918 (Dense)           (None, 4)                 16
#
#  dense_919 (Dense)           (None, 3)                 15
#
#  dense_920 (Dense)           (None, 2)                 8
#
#  dense_921 (Dense)           (None, 1)                 3
#
#  dense_922 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 1.0050 - val_mse: 1.0050
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 1.0032 - val_mse: 1.0032
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 1.0049 - val_mse: 1.0049
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 1.0023 - val_mse: 1.0023
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 1.0041 - val_mse: 1.0041
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 1.0050 - val_mse: 1.0050
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.0049 - val_mse: 1.0049
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 1.0044 - val_mse: 1.0044
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 1.0041 - val_mse: 1.0041
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2240 - val_mse: 1.2240
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2164 - val_mse: 1.2164
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2546 - mse: 0.2546 - val_loss: 1.2139 - val_mse: 1.2139
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 1.2198 - val_mse: 1.2198
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2550 - mse: 0.2550 - val_loss: 1.2277 - val_mse: 1.2277
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2531 - mse: 0.2531 - val_loss: 1.2149 - val_mse: 1.2149
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 1.2178 - val_mse: 1.2178
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2162 - val_mse: 1.2162
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2138 - val_mse: 1.2138
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2542 - mse: 0.2542 - val_loss: 1.2144 - val_mse: 1.2144
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2170 - val_mse: 1.2170
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2293 - val_mse: 1.2293
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2552 - mse: 0.2552 - val_loss: 1.2407 - val_mse: 1.2407
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2238 - val_mse: 1.2238
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2174 - val_mse: 1.2174
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2552 - mse: 0.2552 - val_loss: 1.2146 - val_mse: 1.2146
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2538 - mse: 0.2538 - val_loss: 1.2402 - val_mse: 1.2402
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2546 - mse: 0.2546 - val_loss: 1.2147 - val_mse: 1.2147
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2173 - val_mse: 1.2173
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2139 - val_mse: 1.2139
# Epoch 23/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2552 - mse: 0.2552 - val_loss: 1.2261 - val_mse: 1.2261
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2150 - val_mse: 1.2150
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 1.2315 - val_mse: 1.2315
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 1.2181 - val_mse: 1.2181
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2258 - val_mse: 1.2258
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2186 - val_mse: 1.2186
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2442 - val_mse: 1.2442
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 8.8256e-04 - mse: 8.8256e-04 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.9623e-04 - mse: 7.9623e-04 - val_loss: 1.0089 - val_mse: 1.0089
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.4334e-04 - mse: 7.4334e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5977e-04 - mse: 8.5977e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3842e-04 - mse: 8.3842e-04 - val_loss: 1.0030 - val_mse: 1.0030
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.2708e-04 - mse: 7.2708e-04 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.8079e-04 - mse: 7.8079e-04 - val_loss: 1.0036 - val_mse: 1.0036
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.9178e-04 - mse: 8.9178e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.5864e-04 - mse: 6.5864e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8159e-04 - mse: 9.8159e-04 - val_loss: 1.0067 - val_mse: 1.0067
# Epoch 11/30
# 313/313 [==============================] - 1s 3ms/step - loss: 8.4033e-04 - mse: 8.4033e-04 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 12/30
# 313/313 [==============================] - 1s 3ms/step - loss: 9.2453e-04 - mse: 9.2453e-04 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0152 - val_mse: 1.0152
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0132 - val_mse: 1.0132
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.8171e-04 - mse: 6.8171e-04 - val_loss: 1.0068 - val_mse: 1.0068
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0113 - val_mse: 1.0113
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2715e-04 - mse: 8.2715e-04 - val_loss: 1.0049 - val_mse: 1.0049
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3823e-04 - mse: 8.3823e-04 - val_loss: 1.0037 - val_mse: 1.0037
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0035 - val_mse: 1.0035
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.9012e-04 - mse: 7.9012e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0081 - val_mse: 1.0081
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1708e-04 - mse: 8.1708e-04 - val_loss: 1.0034 - val_mse: 1.0034
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.9813e-04 - mse: 8.9813e-04 - val_loss: 1.0100 - val_mse: 1.0100
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.0417e-04 - mse: 9.0417e-04 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.4182e-04 - mse: 6.4182e-04 - val_loss: 1.0041 - val_mse: 1.0041
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.9610e-04 - mse: 7.9610e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.9416e-04 - mse: 6.9416e-04 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.7021e-04 - mse: 7.7021e-04 - val_loss: 1.0050 - val_mse: 1.0050
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.8597e-04 - mse: 6.8597e-04 - val_loss: 1.0054 - val_mse: 1.0054
# Model: "sequential_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_903 (Dense)           (None, 15)                30
#  dense_904 (Dense)           (None, 1)                 16
#
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_905 (Dense)           (None, 1)                 2
#
#  dense_906 (Dense)           (None, 1)                 2
#
#  dense_907 (Dense)           (None, 1)                 2
#
#  dense_908 (Dense)           (None, 1)                 2
#
#  dense_909 (Dense)           (None, 1)                 2
#
#  dense_910 (Dense)           (None, 1)                 2
#
#  dense_911 (Dense)           (None, 1)                 2
#
#  dense_912 (Dense)           (None, 1)                 2
#
#  dense_913 (Dense)           (None, 1)                 2
#
#  dense_914 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_915 (Dense)           (None, 1)                 2
#
#  dense_916 (Dense)           (None, 2)                 4
#
#  dense_917 (Dense)           (None, 3)                 9
#
#  dense_918 (Dense)           (None, 4)                 16
#
#  dense_919 (Dense)           (None, 3)                 15
#
#  dense_920 (Dense)           (None, 2)                 8
#
#  dense_921 (Dense)           (None, 1)                 3
#
#  dense_922 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.0040 - val_mse: 1.0040
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.0069 - val_mse: 1.0069
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0065 - val_mse: 1.0065
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0060 - val_mse: 1.0060
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2548 - mse: 0.2548 - val_loss: 1.2203 - val_mse: 1.2203
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2181 - val_mse: 1.2181
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2154 - val_mse: 1.2154
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2546 - mse: 0.2546 - val_loss: 1.2142 - val_mse: 1.2142
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2265 - val_mse: 1.2265
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2538 - mse: 0.2538 - val_loss: 1.2629 - val_mse: 1.2629
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2362 - val_mse: 1.2362
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2548 - mse: 0.2548 - val_loss: 1.2299 - val_mse: 1.2299
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2554 - mse: 0.2554 - val_loss: 1.2146 - val_mse: 1.2146
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2270 - val_mse: 1.2270
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2318 - val_mse: 1.2318
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2147 - val_mse: 1.2147
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2265 - val_mse: 1.2265
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2394 - val_mse: 1.2394
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2151 - val_mse: 1.2151
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2187 - val_mse: 1.2187
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2138 - val_mse: 1.2138
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2333 - val_mse: 1.2333
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2529 - mse: 0.2529 - val_loss: 1.2305 - val_mse: 1.2305
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2181 - val_mse: 1.2181
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2552 - mse: 0.2552 - val_loss: 1.2165 - val_mse: 1.2165
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2171 - val_mse: 1.2171
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2152 - val_mse: 1.2152
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2343 - val_mse: 1.2343
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2352 - val_mse: 1.2352
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2548 - mse: 0.2548 - val_loss: 1.2161 - val_mse: 1.2161
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2143 - val_mse: 1.2143
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2149 - val_mse: 1.2149
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2135 - val_mse: 1.2135
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2545 - mse: 0.2545 - val_loss: 1.2190 - val_mse: 1.2190
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 6.9195e-04 - mse: 6.9195e-04 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3189e-04 - mse: 6.3189e-04 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.8755e-04 - mse: 5.8755e-04 - val_loss: 1.0068 - val_mse: 1.0068
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0034 - val_mse: 1.0034
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8842e-04 - mse: 8.8842e-04 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.6898e-04 - mse: 6.6898e-04 - val_loss: 1.0068 - val_mse: 1.0068
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.5260e-04 - mse: 7.5260e-04 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.6111e-04 - mse: 7.6111e-04 - val_loss: 1.0082 - val_mse: 1.0082
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0071 - val_mse: 1.0071
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.5898e-04 - mse: 7.5898e-04 - val_loss: 1.0073 - val_mse: 1.0073
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.8996e-04 - mse: 7.8996e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.2444e-04 - mse: 6.2444e-04 - val_loss: 1.0032 - val_mse: 1.0032
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 1.0069 - val_mse: 1.0069
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.6009e-04 - mse: 7.6009e-04 - val_loss: 1.0075 - val_mse: 1.0075
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 1.0067 - val_mse: 1.0067
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.7534e-04 - mse: 5.7534e-04 - val_loss: 1.0070 - val_mse: 1.0070
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.6822e-04 - mse: 7.6822e-04 - val_loss: 1.0067 - val_mse: 1.0067
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.7315e-04 - mse: 9.7315e-04 - val_loss: 1.0067 - val_mse: 1.0067
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.1310e-04 - mse: 5.1310e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0072 - val_mse: 1.0072
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.5257e-04 - mse: 6.5257e-04 - val_loss: 1.0169 - val_mse: 1.0169
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.8815e-04 - mse: 5.8815e-04 - val_loss: 1.0039 - val_mse: 1.0039
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.2131e-04 - mse: 6.2131e-04 - val_loss: 1.0049 - val_mse: 1.0049
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.6041e-04 - mse: 4.6041e-04 - val_loss: 1.0070 - val_mse: 1.0070
# Model: "sequential_138"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_903 (Dense)           (None, 15)                30
#
#  dense_904 (Dense)           (None, 1)                 16
#
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_905 (Dense)           (None, 1)                 2
#
#  dense_906 (Dense)           (None, 1)                 2
#
#  dense_907 (Dense)           (None, 1)                 2
#
#  dense_908 (Dense)           (None, 1)                 2
#
#  dense_909 (Dense)           (None, 1)                 2
#
#  dense_910 (Dense)           (None, 1)                 2
#
#  dense_911 (Dense)           (None, 1)                 2
#
#  dense_912 (Dense)           (None, 1)                 2
#
#  dense_913 (Dense)           (None, 1)                 2
#
#  dense_914 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_915 (Dense)           (None, 1)                 2
#
#  dense_916 (Dense)           (None, 2)                 4
#
#  dense_917 (Dense)           (None, 3)                 9
#
#  dense_918 (Dense)           (None, 4)                 16
#
#  dense_919 (Dense)           (None, 3)                 15
#
#  dense_920 (Dense)           (None, 2)                 8
#
#  dense_921 (Dense)           (None, 1)                 3
#
#  dense_922 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0060 - val_mse: 1.0060
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 1.0073 - val_mse: 1.0073
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 1.0066 - val_mse: 1.0066
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0070 - val_mse: 1.0070
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0060 - val_mse: 1.0060
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0049 - val_mse: 1.0049
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0058 - val_mse: 1.0058
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 1.0066 - val_mse: 1.0066
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2171 - val_mse: 1.2171
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2153 - val_mse: 1.2153
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2142 - val_mse: 1.2142
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2546 - mse: 0.2546 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2549 - mse: 0.2549 - val_loss: 1.2292 - val_mse: 1.2292
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2542 - mse: 0.2542 - val_loss: 1.2230 - val_mse: 1.2230
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2231 - val_mse: 1.2231
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2135 - val_mse: 1.2135
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2195 - val_mse: 1.2195
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2535 - mse: 0.2535 - val_loss: 1.2143 - val_mse: 1.2143
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2551 - mse: 0.2551 - val_loss: 1.2153 - val_mse: 1.2153
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2529 - mse: 0.2529 - val_loss: 1.2174 - val_mse: 1.2174
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2347 - val_mse: 1.2347
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2526 - mse: 0.2526 - val_loss: 1.2168 - val_mse: 1.2168
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2151 - val_mse: 1.2151
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2532 - mse: 0.2532 - val_loss: 1.2343 - val_mse: 1.2343
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2214 - val_mse: 1.2214
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2142 - val_mse: 1.2142
# Epoch 21/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2223 - val_mse: 1.2223
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2252 - val_mse: 1.2252
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2192 - val_mse: 1.2192
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2549 - mse: 0.2549 - val_loss: 1.2138 - val_mse: 1.2138
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2164 - val_mse: 1.2164
# Epoch 26/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2216 - val_mse: 1.2216
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2340 - val_mse: 1.2340
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2533 - mse: 0.2533 - val_loss: 1.2227 - val_mse: 1.2227
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2542 - mse: 0.2542 - val_loss: 1.2172 - val_mse: 1.2172
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2542 - mse: 0.2542 - val_loss: 1.2202 - val_mse: 1.2202
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 7.4054e-04 - mse: 7.4054e-04 - val_loss: 1.0036 - val_mse: 1.0036
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0105 - val_mse: 1.0105
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.6091e-04 - mse: 5.6091e-04 - val_loss: 1.0066 - val_mse: 1.0066
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3102e-04 - mse: 6.3102e-04 - val_loss: 1.0050 - val_mse: 1.0050
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0036 - val_mse: 1.0036
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.0962e-04 - mse: 7.0962e-04 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.4637e-04 - mse: 6.4637e-04 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.9866e-04 - mse: 6.9866e-04 - val_loss: 1.0072 - val_mse: 1.0072
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.2912e-04 - mse: 6.2912e-04 - val_loss: 1.0037 - val_mse: 1.0037
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.4420e-04 - mse: 4.4420e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.2905e-04 - mse: 6.2905e-04 - val_loss: 1.0061 - val_mse: 1.0061
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.0931e-04 - mse: 8.0931e-04 - val_loss: 1.0034 - val_mse: 1.0034
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.7661e-04 - mse: 6.7661e-04 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8631e-04 - mse: 8.8631e-04 - val_loss: 1.0131 - val_mse: 1.0131
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.5253e-04 - mse: 5.5253e-04 - val_loss: 1.0073 - val_mse: 1.0073
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.9254e-04 - mse: 5.9254e-04 - val_loss: 1.0042 - val_mse: 1.0042
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8641e-04 - mse: 8.8641e-04 - val_loss: 1.0105 - val_mse: 1.0105
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5768e-04 - mse: 8.5768e-04 - val_loss: 1.0043 - val_mse: 1.0043
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.8082e-04 - mse: 5.8082e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3297e-04 - mse: 6.3297e-04 - val_loss: 1.0037 - val_mse: 1.0037
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6973e-04 - mse: 8.6973e-04 - val_loss: 1.0035 - val_mse: 1.0035
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 1.0083 - val_mse: 1.0083
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3393e-04 - mse: 8.3393e-04 - val_loss: 1.0041 - val_mse: 1.0041
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2837e-04 - mse: 8.2837e-04 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.5576e-04 - mse: 6.5576e-04 - val_loss: 1.0050 - val_mse: 1.0050
# Model: "sequential_138"
# ...
#
#  dense_904 (Dense)           (None, 1)                 16
#
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_139"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_905 (Dense)           (None, 1)                 2
#
#  dense_906 (Dense)           (None, 1)                 2
#
#  dense_907 (Dense)           (None, 1)                 2
#
#  dense_908 (Dense)           (None, 1)                 2
#
#  dense_909 (Dense)           (None, 1)                 2
#
#  dense_910 (Dense)           (None, 1)                 2
#
#  dense_911 (Dense)           (None, 1)                 2
#
#  dense_912 (Dense)           (None, 1)                 2
#
#  dense_913 (Dense)           (None, 1)                 2
#
#  dense_914 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_140"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_915 (Dense)           (None, 1)                 2
#
#  dense_916 (Dense)           (None, 2)                 4
#
#  dense_917 (Dense)           (None, 3)                 9
#
#  dense_918 (Dense)           (None, 4)                 16
#
#  dense_919 (Dense)           (None, 3)                 15
#
#  dense_920 (Dense)           (None, 2)                 8
#
#  dense_921 (Dense)           (None, 1)                 3
#
#  dense_922 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.4593e-04 - mse: 9.4593e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.4253e-04 - mse: 9.4253e-04 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.3800e-04 - mse: 9.3800e-04 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.2720e-04 - mse: 9.2720e-04 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.2517e-04 - mse: 9.2517e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.1866e-04 - mse: 9.1866e-04 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.1194e-04 - mse: 9.1194e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.1129e-04 - mse: 9.1129e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.0771e-04 - mse: 9.0771e-04 - val_loss: 1.0064 - val_mse: 1.0064
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.0010e-04 - mse: 9.0010e-04 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.9656e-04 - mse: 8.9656e-04 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8687e-04 - mse: 8.8687e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8344e-04 - mse: 8.8344e-04 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.8174e-04 - mse: 8.8174e-04 - val_loss: 1.0050 - val_mse: 1.0050
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.7883e-04 - mse: 8.7883e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.7091e-04 - mse: 8.7091e-04 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6564e-04 - mse: 8.6564e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6473e-04 - mse: 8.6473e-04 - val_loss: 1.0066 - val_mse: 1.0066
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6260e-04 - mse: 8.6260e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.5071e-04 - mse: 8.5071e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.4996e-04 - mse: 8.4996e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.4417e-04 - mse: 8.4417e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.4176e-04 - mse: 8.4176e-04 - val_loss: 1.0057 - val_mse: 1.0057
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3983e-04 - mse: 8.3983e-04 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3989e-04 - mse: 8.3989e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.3001e-04 - mse: 8.3001e-04 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2957e-04 - mse: 8.2957e-04 - val_loss: 1.0056 - val_mse: 1.0056
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2788e-04 - mse: 8.2788e-04 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.2145e-04 - mse: 8.2145e-04 - val_loss: 1.0052 - val_mse: 1.0052
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.1590e-04 - mse: 8.1590e-04 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2530 - mse: 0.2530 - val_loss: 1.2138 - val_mse: 1.2138
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2177 - val_mse: 1.2177
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2145 - val_mse: 1.2145
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2141 - val_mse: 1.2141
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2198 - val_mse: 1.2198
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2280 - val_mse: 1.2280
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2544 - mse: 0.2544 - val_loss: 1.2251 - val_mse: 1.2251
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2414 - val_mse: 1.2414
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2232 - val_mse: 1.2232
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2534 - mse: 0.2534 - val_loss: 1.2144 - val_mse: 1.2144
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2531 - mse: 0.2531 - val_loss: 1.2137 - val_mse: 1.2137
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2191 - val_mse: 1.2191
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2535 - mse: 0.2535 - val_loss: 1.2167 - val_mse: 1.2167
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2139 - val_mse: 1.2139
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2539 - mse: 0.2539 - val_loss: 1.2139 - val_mse: 1.2139
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2536 - mse: 0.2536 - val_loss: 1.2338 - val_mse: 1.2338
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2549 - mse: 0.2549 - val_loss: 1.2211 - val_mse: 1.2211
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2531 - mse: 0.2531 - val_loss: 1.2144 - val_mse: 1.2144
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2530 - mse: 0.2530 - val_loss: 1.2134 - val_mse: 1.2134
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2531 - mse: 0.2531 - val_loss: 1.2176 - val_mse: 1.2176
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2495 - val_mse: 1.2495
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2547 - mse: 0.2547 - val_loss: 1.2140 - val_mse: 1.2140
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2679 - val_mse: 1.2679
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2543 - mse: 0.2543 - val_loss: 1.2224 - val_mse: 1.2224
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2540 - mse: 0.2540 - val_loss: 1.2222 - val_mse: 1.2222
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2212 - val_mse: 1.2212
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2542 - mse: 0.2542 - val_loss: 1.2168 - val_mse: 1.2168
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2537 - mse: 0.2537 - val_loss: 1.2161 - val_mse: 1.2161
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2166 - val_mse: 1.2166
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2541 - mse: 0.2541 - val_loss: 1.2207 - val_mse: 1.2207
# Epoch 1/30
# 313/313 [==============================] - 1s 3ms/step - loss: 6.9727e-04 - mse: 6.9727e-04 - val_loss: 1.0047 - val_mse: 1.0047
# Epoch 2/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 3/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.1932e-04 - mse: 5.1932e-04 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 4/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.5799e-04 - mse: 5.5799e-04 - val_loss: 1.0054 - val_mse: 1.0054
# Epoch 5/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.7621e-04 - mse: 6.7621e-04 - val_loss: 1.0090 - val_mse: 1.0090
# Epoch 6/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 7/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.2288e-04 - mse: 4.2288e-04 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 8/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3286e-04 - mse: 6.3286e-04 - val_loss: 1.0042 - val_mse: 1.0042
# Epoch 9/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.6533e-04 - mse: 6.6533e-04 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 10/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.0887e-04 - mse: 5.0887e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 11/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.9459e-04 - mse: 4.9459e-04 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 12/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.8490e-04 - mse: 4.8490e-04 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 13/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.6351e-04 - mse: 8.6351e-04 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 14/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 1.0044 - val_mse: 1.0044
# Epoch 15/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 1.0038 - val_mse: 1.0038
# Epoch 16/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 1.0042 - val_mse: 1.0042
# Epoch 17/30
# 313/313 [==============================] - 1s 2ms/step - loss: 3.7690e-04 - mse: 3.7690e-04 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 18/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.2687e-04 - mse: 5.2687e-04 - val_loss: 1.0062 - val_mse: 1.0062
# Epoch 19/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.7562e-04 - mse: 6.7562e-04 - val_loss: 1.0059 - val_mse: 1.0059
# Epoch 20/30
# 313/313 [==============================] - 1s 2ms/step - loss: 7.4629e-04 - mse: 7.4629e-04 - val_loss: 1.0042 - val_mse: 1.0042
# Epoch 21/30
# 313/313 [==============================] - 1s 2ms/step - loss: 8.9914e-04 - mse: 8.9914e-04 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 22/30
# 313/313 [==============================] - 1s 2ms/step - loss: 9.4180e-04 - mse: 9.4180e-04 - val_loss: 1.0035 - val_mse: 1.0035
# Epoch 23/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.8742e-04 - mse: 6.8742e-04 - val_loss: 1.0037 - val_mse: 1.0037
# Epoch 24/30
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3917e-04 - mse: 6.3917e-04 - val_loss: 1.0042 - val_mse: 1.0042
# Epoch 25/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.5494e-04 - mse: 5.5494e-04 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 26/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.8110e-04 - mse: 5.8110e-04 - val_loss: 1.0035 - val_mse: 1.0035
# Epoch 27/30
# 313/313 [==============================] - 1s 2ms/step - loss: 5.4979e-04 - mse: 5.4979e-04 - val_loss: 1.0045 - val_mse: 1.0045
# Epoch 28/30
# 313/313 [==============================] - 1s 2ms/step - loss: 3.6794e-04 - mse: 3.6794e-04 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 29/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.0459e-04 - mse: 4.0459e-04 - val_loss: 1.0072 - val_mse: 1.0072
# Epoch 30/30
# 313/313 [==============================] - 1s 2ms/step - loss: 4.8285e-04 - mse: 4.8285e-04 - val_loss: 1.0047 - val_mse: 1.0047

# %%
def fit(model, x_valid, y_target,title_activation):
    plt.figure(figsize=(15,6))
    for lim in range(2):
        plt.subplot(1,2,lim+1)
        x_pred = np.random.uniform(-lim-1, lim+1, 200)
        plt.plot(x_valid, y_target)
        y_pred=model.predict(x_pred)
        plt.scatter(x_pred,y_pred,marker='.',label=mod_names[i])

        if(lim==0):
            plt.xlim(-1.1,1.1)
            plt.ylim(1,5)
        plt.legend(loc='best')
        plt.grid(True)
        if(lim==0): plt.title('inside training range')
        else: plt.title('outside training range')
    plt.suptitle(f"Models prediction with {title_activation} activation")
    plt.show()

# %%
multimodels.append(models)
i = 0
for mod in multimodels: 
    fit(mod,x_valid,y_target,activation[i])
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4026/1829634305.py in <module>
#       2 i = 0
#       3 for mod in multimodels:
# ----> 4     fit(mod,x_valid,y_target,activation[i])
#       5     i=i+1
#
# /tmp/ipykernel_4026/1679571966.py in fit(model, x_valid, y_target, title_activation)
#       5         x_pred = np.random.uniform(-lim-1, lim+1, 200)
#       6         plt.plot(x_valid, y_target)
# ----> 7         y_pred=model.predict(x_pred)
#       8         plt.scatter(x_pred,y_pred,marker='.',label=mod_names[i])
#       9
#
# AttributeError: 'list' object has no attribute 'predict'

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>
