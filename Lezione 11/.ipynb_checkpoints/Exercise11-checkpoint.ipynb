# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import os
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD, Adam, Adadelta
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

import matplotlib.style as style 
style.use('tableau-colorblind10')
# Out:
# 2022-07-01 17:48:34.871482: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-01 17:48:34.871512: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# The goal of this exercises is to perform ML regression on noisy data usign a feedforward neural network (NN).
#
# The universal approximation theorem guarantees that Neural Networks can transform (non linearly) the input $X$ into an output $Y$ that depends on the weights and biases of all the neurons in the network, whatever it is the form of the function that links $X$ to $Y$.
#
# We will be using a [Sequential model](https://keras.io/guides/sequential_model/) to model the layers of our network.
#
# We will takle the **prediction problem**: given a probabilistic process that outputs labeled data $(x,y)$, with $y_i = f(x_i)+\eta_i$, $\eta_i$ gaussian and uncorrelated noise such that: $\langle \eta_i \rangle=0$ and $\langle \eta_i \eta_j \rangle=\delta_{ij}\sigma$, the output of our neural network will provide us with a set of prediction $\{ y_j^{\text{pred}} \}$. To measure the goodness of our hypothesis we measure on the test set the sum of the mean square error (MSE).
#
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$

# %% [markdown]
# # Exercise 11.1
# ### Linear regression

# %% [markdown]
# Our first steps should be easy ones, so in this exercise we have a dataset distributed following:
#
# $$
# f(x) = 2x +1.
# $$
#
# In this case a network of a single layer and a single neuron is enough to tackle the problem.
#
# The only parameters to be optimized will be the weights $w_j$ and the biases $b_j$. At first the parameters we will use are: $N_{\text{train}}=100$ and $N_{\text{valid}}=10$ (our test values, in this case directly sampled from the analytical model). Our network will be trained using **30 epochs**, the noise is $\sigma=0$. We explore how changing this values will impact the predictive power of our model.

# %% [markdown]
# As a first thing, we generate and plot a set of input data that will be used as training set and test set.

# %%
def generate_input(n_train,m,b,sigma):
    # generate training inputs
    n_valid = int(n_train/10)
    np.random.seed(0)
    x_train = np.random.uniform(-1, 1, n_train)
    x_valid = np.random.uniform(-1, 1, n_valid)
    x_valid.sort()
    y_target = m * x_valid + b # ideal (target) linear function

    y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
    y_valid = np.random.normal(m * x_valid + b, sigma)
    return x_train, x_valid, y_target ,y_train, y_valid

def Set_model(n_node):
    # compose the NN model
    model = tf.keras.Sequential()
    model.add(Dense(n_node, input_shape=(1,)))#let add just one layer and one node.

    # compile the model choosing optimizer, loss and metrics objects
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

    # get a summary of our composed model
    model.summary()
    
    # save the weights that we will use later
    model.save_weights('model.h5')
    return model
    
def Test(n_epochs):
    #test my model
    history = model.fit(x=x_train, y=y_train, 
            batch_size=32, epochs=n_epochs,
            shuffle=True, # a good idea is to shuffle input before at each epoch
            validation_data=(x_valid, y_valid),
            verbose = 0)
    return history;

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
def plot_model(): 
    par = model.get_weights()

    #print('\n\n------------------------------------------------------\n')
    #print('The model function obtained is: \n\nf(x) = '+ str(float(par[0]))+'x + ' +str(float(par[1])))
    #print('\n\n------------------------------------------------------')

    # look into training history
    # Plot training & validation loss values
    plt. subplots(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss', fontsize=16)
    plt.grid()
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Validation'], loc='best')

    # Plot target and fit
    plt.subplot(1,2,2)
    plt.title('Target function and predicted function', fontsize=16)
    x_predicted = np.random.uniform(-1, 1, 100)
    y_predicted = model.predict(x_predicted)
    # Fitted function
    plt.plot(x_predicted, y_predicted,'ro', label='predicted')
    # Target function
    plt.plot(x_valid, y_target, label='target')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_perf(model, y_target, x_valid, y_valid,bs):
    print('\n\n------------------------------------------------------\n')
    # evaluate model
    score = model.evaluate(x_valid, y_target, batch_size=bs, verbose=1)

    # print performance
    print()
    print('Evaluation of the model by comparison with the exact curve:')
    print('Test loss:', score[0])
    print('Test accuracy:', score[1])

    print('\n\n------------------------------------------------------')

# %%
#TEST 1
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect
sigma = 0.0 # noise standard deviation, for the moment it is absent
n_train = 300
n_epochs = 30
n_node = 1
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#setting model
model = Set_model(n_node)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# 2022-07-01 17:48:36.880442: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-01 17:48:36.880488: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-01 17:48:36.880517: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (edd-VivoBook-ASUSLaptop-X521IA-M533IA): /proc/driver/nvidia/version does not exist
# 2022-07-01 17:48:36.881027: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0074 - mse: 0.0074
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.007422966882586479
# Test accuracy: 0.007422966882586479
#
#
# ------------------------------------------------------

# %% [markdown]
# **OBSERVATION**
#
#
# First we ran the model with 300 trains, using 10% of trains are used to validate the test, and 30 epochs
#
# Left plot show that to improve results is enough to increase the number of epochs.
# Actually the mean square error trend tend toward zero.

# %% [markdown]
# **Test 2**: **increase the number of epochs from 30 to 100**

# %%
#TEST 2
n_train = 300
n_epochs = 100

#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 24ms/step - loss: 5.8473e-07 - mse: 5.8473e-07
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 5.84732333663851e-07
# Test accuracy: 5.84732333663851e-07
#
#
# ------------------------------------------------------

# %% [markdown]
# ### OBSERVATION
#
# ccuracy has improved appreciably.
#
# We now test the model by increasing the number of throws and leaving the number of epochs unchanged.

# %%
#TEST 3
n_train = 1000
n_epochs = 30

#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1416e-06 - mse: 1.1416e-06
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 1.141640041169012e-06
# Test accuracy: 1.141640041169012e-06
#
#
# ------------------------------------------------------

# %% [markdown]
# ### OBSERVATION
#
# Matching loss tests one could observe that **more training is better than more epochs**.
# Actually larger training set provides loss values much smaller than those previously obtained. Now the loss function coverges to zero after 10 epochs going 3ms/step, while previusly the loss function coverges to zero after 40 epochs going 22ms/step.

# %%
#TEST 4
n_train = 1000
n_epochs = 100
sigma = 0.5
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train,m,b,sigma)

#load weights
model.load_weights('model.h5')

#starting model
history = Test(n_epochs)

#plot
plot_model()
plot_perf(model, y_target, x_valid, y_valid, 32)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# ------------------------------------------------------
#
# 4/4 [==============================] - 0s 2ms/step - loss: 4.7405e-05 - mse: 4.7405e-05
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 4.740516669698991e-05
# Test accuracy: 4.740516669698991e-05
#
#
# ------------------------------------------------------

# %% [markdown]
# Obviusly introducing a noise in dataset generator lead to worse results. In addiction one could observe the loss curve got a gap between validation values. This gap show us we are not overstiming the results.

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# Find good (& reasonable) choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Check your NN model by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
def polynomial(x):
    return 4-3*x-2*x*x+3*x*x*x

def generate_input(n_train):
    # generate training inputs
    n_valid = 100
    np.random.seed(0)
    x_train = np.random.uniform(-1, 1, n_train)
    x_valid = np.random.uniform(-1, 1, n_valid)
    x_valid.sort()
    
    y_target = polynomial(x_valid) # ideal (target) linear function
    y_valid = np.random.normal(polynomial(x_valid))

    y_train = np.random.normal(polynomial(x_train)) # actual measures from which we want to guess regression parameters

    return x_train, x_valid, y_target ,y_train, y_valid

#define models
def Set_model(n_layer, n_node,activation):
    
    # compose the model with more nodes
    Nod_mod = tf.keras.Sequential()
    Nod_mod.add(Dense(1, input_shape=(1,),activation=activation))
    Nod_mod.add(Dense(n_node, input_shape=(1,),activation=activation))
    Nod_mod.add(Dense(1, input_shape=(1,),activation=activation))
    
    # compose the model with more layer
    Lay_mod = tf.keras.Sequential()
    for i in range(n_layer): Lay_mod.add(Dense(1, input_shape=(1,),activation=activation))

    # compose the model with more layer & more nodes
    Mix_mod = tf.keras.Sequential()
    Mix_mod.add(Dense(1, input_shape=(1,),activation=activation))
    for i in range(3): Mix_mod.add(Dense(2+i, input_shape=(1,),activation=activation))
    for i in range(3): Mix_mod.add(Dense(3-i, input_shape=(1,),activation=activation))
    Mix_mod.add(Dense(1, input_shape=(1,),activation=activation))

    return [Nod_mod, Lay_mod, Mix_mod]

def Compile(models, opt,loss,met,mod_names):
    i=0
    for model in models:
        model.compile(optimizer=opt, loss=loss, metrics=[met])
        model.save_weights(f'{model}.h5')
        model.summary(); print()
        i=i+1
    
def History(models,n_epochs,mod_names): #training model with history database
    #load weights
    j=0
    history = []
    for model in models: 
        model.load_weights(f'{model}.h5')
        history.append(model.fit(x = x_train, y = y_train, 
          batch_size=150, epochs=n_epochs, shuffle=True,
          validation_data=(x_valid, y_valid), verbose=1))
        j=j+1
    return history

# %%
n_train = 20000
n_epochs = 30
n_layer = 10
n_node = 15
mod_names = ["MORE NODE","MORE LAYER","MORE NODE & LAYER"]
#generate input data
x_train, x_valid, y_target ,y_train, y_valid = generate_input(n_train)

#setting model
models = Set_model(n_layer, n_node, "elu")

#compiling
Compile(models, 'sgd','mse','mse',mod_names)#SGD o Adam

#starting model
histo = History(models,n_epochs,mod_names)
# Out:
# Model: "sequential_43"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_295 (Dense)           (None, 1)                 2
#
#  dense_296 (Dense)           (None, 15)                30
#
#  dense_297 (Dense)           (None, 1)                 16
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_44"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_298 (Dense)           (None, 1)                 2
#
#  dense_299 (Dense)           (None, 1)                 2
#
#  dense_300 (Dense)           (None, 1)                 2
#
#  dense_301 (Dense)           (None, 1)                 2
#
#  dense_302 (Dense)           (None, 1)                 2
#
#  dense_303 (Dense)           (None, 1)                 2
#
#  dense_304 (Dense)           (None, 1)                 2
#
#  dense_305 (Dense)           (None, 1)                 2
#
#  dense_306 (Dense)           (None, 1)                 2
#
#  dense_307 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_45"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_308 (Dense)           (None, 1)                 2
#
#  dense_309 (Dense)           (None, 2)                 4
#
#  dense_310 (Dense)           (None, 3)                 9
#
#  dense_311 (Dense)           (None, 4)                 16
#
#  dense_312 (Dense)           (None, 3)                 15
#
#  dense_313 (Dense)           (None, 2)                 8
#
#  dense_314 (Dense)           (None, 1)                 3
#
#  dense_315 (Dense)           (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 134/134 [==============================] - 1s 4ms/step - loss: 2.3178 - mse: 2.3178 - val_loss: 1.4725 - val_mse: 1.4725
# Epoch 2/30
# 134/134 [==============================] - 0s 3ms/step - loss: 1.5544 - mse: 1.5544 - val_loss: 1.4334 - val_mse: 1.4334
# Epoch 3/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.5146 - mse: 1.5146 - val_loss: 1.3954 - val_mse: 1.3954
# Epoch 4/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.4588 - mse: 1.4588 - val_loss: 1.3276 - val_mse: 1.3276
# Epoch 5/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.3782 - mse: 1.3782 - val_loss: 1.2533 - val_mse: 1.2533
# Epoch 6/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.2789 - mse: 1.2789 - val_loss: 1.1458 - val_mse: 1.1458
# Epoch 7/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.1908 - mse: 1.1908 - val_loss: 1.1003 - val_mse: 1.1003
# Epoch 8/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.1288 - mse: 1.1288 - val_loss: 1.0458 - val_mse: 1.0458
# Epoch 9/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0895 - mse: 1.0895 - val_loss: 1.0375 - val_mse: 1.0375
# Epoch 10/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0664 - mse: 1.0664 - val_loss: 1.0305 - val_mse: 1.0305
# Epoch 11/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0525 - mse: 1.0525 - val_loss: 1.0297 - val_mse: 1.0297
# Epoch 12/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0446 - mse: 1.0446 - val_loss: 0.9968 - val_mse: 0.9968
# Epoch 13/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0400 - mse: 1.0400 - val_loss: 0.9990 - val_mse: 0.9990
# Epoch 14/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0370 - mse: 1.0370 - val_loss: 1.0048 - val_mse: 1.0048
# Epoch 15/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0358 - mse: 1.0358 - val_loss: 0.9951 - val_mse: 0.9951
# Epoch 16/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0339 - mse: 1.0339 - val_loss: 1.0207 - val_mse: 1.0207
# Epoch 17/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0332 - mse: 1.0332 - val_loss: 0.9781 - val_mse: 0.9781
# Epoch 18/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0325 - mse: 1.0325 - val_loss: 0.9816 - val_mse: 0.9816
# Epoch 19/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0322 - mse: 1.0322 - val_loss: 0.9953 - val_mse: 0.9953
# Epoch 20/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0317 - mse: 1.0317 - val_loss: 1.0111 - val_mse: 1.0111
# Epoch 21/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0314 - mse: 1.0314 - val_loss: 0.9832 - val_mse: 0.9832
# Epoch 22/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0304 - mse: 1.0304 - val_loss: 0.9918 - val_mse: 0.9918
# Epoch 23/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0300 - mse: 1.0300 - val_loss: 0.9816 - val_mse: 0.9816
# Epoch 24/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0295 - mse: 1.0295 - val_loss: 1.0002 - val_mse: 1.0002
# Epoch 25/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0294 - mse: 1.0294 - val_loss: 0.9856 - val_mse: 0.9856
# Epoch 26/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0286 - mse: 1.0286 - val_loss: 0.9917 - val_mse: 0.9917
# Epoch 27/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0283 - mse: 1.0283 - val_loss: 0.9795 - val_mse: 0.9795
# Epoch 28/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0281 - mse: 1.0281 - val_loss: 0.9975 - val_mse: 0.9975
# Epoch 29/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0264 - mse: 1.0264 - val_loss: 0.9708 - val_mse: 0.9708
# Epoch 30/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0266 - mse: 1.0266 - val_loss: 0.9748 - val_mse: 0.9748
# Epoch 1/30
# 134/134 [==============================] - 1s 4ms/step - loss: 2.9062 - mse: 2.9062 - val_loss: 2.1619 - val_mse: 2.1619
# Epoch 2/30
# 134/134 [==============================] - 0s 3ms/step - loss: 2.0563 - mse: 2.0563 - val_loss: 2.1620 - val_mse: 2.1620
# Epoch 3/30
# 134/134 [==============================] - 0s 3ms/step - loss: 2.0565 - mse: 2.0565 - val_loss: 2.1618 - val_mse: 2.1618
# Epoch 4/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0562 - mse: 2.0562 - val_loss: 2.1618 - val_mse: 2.1618
# Epoch 5/30
# 134/134 [==============================] - 0s 3ms/step - loss: 2.0562 - mse: 2.0562 - val_loss: 2.1620 - val_mse: 2.1620
# Epoch 6/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0562 - mse: 2.0562 - val_loss: 2.1618 - val_mse: 2.1618
# Epoch 7/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0562 - mse: 2.0562 - val_loss: 2.1619 - val_mse: 2.1619
# Epoch 8/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0561 - mse: 2.0561 - val_loss: 2.1616 - val_mse: 2.1616
# Epoch 9/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0561 - mse: 2.0561 - val_loss: 2.1618 - val_mse: 2.1618
# Epoch 10/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0560 - mse: 2.0560 - val_loss: 2.1615 - val_mse: 2.1615
# Epoch 11/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0559 - mse: 2.0559 - val_loss: 2.1613 - val_mse: 2.1613
# Epoch 12/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0555 - mse: 2.0555 - val_loss: 2.1635 - val_mse: 2.1635
# Epoch 13/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0561 - mse: 2.0561 - val_loss: 2.1611 - val_mse: 2.1611
# Epoch 14/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0556 - mse: 2.0556 - val_loss: 2.1609 - val_mse: 2.1609
# Epoch 15/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0555 - mse: 2.0555 - val_loss: 2.1607 - val_mse: 2.1607
# Epoch 16/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0554 - mse: 2.0554 - val_loss: 2.1608 - val_mse: 2.1608
# Epoch 17/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0550 - mse: 2.0550 - val_loss: 2.1600 - val_mse: 2.1600
# Epoch 18/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0548 - mse: 2.0548 - val_loss: 2.1595 - val_mse: 2.1595
# Epoch 19/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0544 - mse: 2.0544 - val_loss: 2.1590 - val_mse: 2.1590
# Epoch 20/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0537 - mse: 2.0537 - val_loss: 2.1586 - val_mse: 2.1586
# Epoch 21/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0527 - mse: 2.0527 - val_loss: 2.1567 - val_mse: 2.1567
# Epoch 22/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0512 - mse: 2.0512 - val_loss: 2.1539 - val_mse: 2.1539
# Epoch 23/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0482 - mse: 2.0482 - val_loss: 2.1478 - val_mse: 2.1478
# Epoch 24/30
# 134/134 [==============================] - 0s 2ms/step - loss: 2.0393 - mse: 2.0393 - val_loss: 2.1255 - val_mse: 2.1255
# Epoch 25/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.9295 - mse: 1.9295 - val_loss: 1.4782 - val_mse: 1.4782
# Epoch 26/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.3399 - mse: 1.3399 - val_loss: 1.1897 - val_mse: 1.1897
# Epoch 27/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.3006 - mse: 1.3006 - val_loss: 1.1869 - val_mse: 1.1869
# Epoch 28/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.2912 - mse: 1.2912 - val_loss: 1.2125 - val_mse: 1.2125
# Epoch 29/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.2851 - mse: 1.2851 - val_loss: 1.1950 - val_mse: 1.1950
# Epoch 30/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.2819 - mse: 1.2819 - val_loss: 1.1853 - val_mse: 1.1853
# Epoch 1/30
# 134/134 [==============================] - 1s 3ms/step - loss: 3.5734 - mse: 3.5734 - val_loss: 1.1919 - val_mse: 1.1919
# Epoch 2/30
# 134/134 [==============================] - 0s 3ms/step - loss: 1.2507 - mse: 1.2507 - val_loss: 1.1332 - val_mse: 1.1332
# Epoch 3/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.1907 - mse: 1.1907 - val_loss: 1.1023 - val_mse: 1.1023
# Epoch 4/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.1313 - mse: 1.1313 - val_loss: 1.0872 - val_mse: 1.0872
# Epoch 5/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0911 - mse: 1.0911 - val_loss: 1.0300 - val_mse: 1.0300
# Epoch 6/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0714 - mse: 1.0714 - val_loss: 1.0070 - val_mse: 1.0070
# Epoch 7/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0589 - mse: 1.0589 - val_loss: 1.0064 - val_mse: 1.0064
# Epoch 8/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0498 - mse: 1.0498 - val_loss: 0.9979 - val_mse: 0.9979
# Epoch 9/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0412 - mse: 1.0412 - val_loss: 0.9893 - val_mse: 0.9893
# Epoch 10/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0351 - mse: 1.0351 - val_loss: 0.9871 - val_mse: 0.9871
# Epoch 11/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0309 - mse: 1.0309 - val_loss: 1.0536 - val_mse: 1.0536
# Epoch 12/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0276 - mse: 1.0276 - val_loss: 0.9742 - val_mse: 0.9742
# Epoch 13/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0240 - mse: 1.0240 - val_loss: 0.9544 - val_mse: 0.9544
# Epoch 14/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0233 - mse: 1.0233 - val_loss: 0.9479 - val_mse: 0.9479
# Epoch 15/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0202 - mse: 1.0202 - val_loss: 0.9659 - val_mse: 0.9659
# Epoch 16/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0215 - mse: 1.0215 - val_loss: 0.9445 - val_mse: 0.9445
# Epoch 17/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0187 - mse: 1.0187 - val_loss: 0.9402 - val_mse: 0.9402
# Epoch 18/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0177 - mse: 1.0177 - val_loss: 0.9617 - val_mse: 0.9617
# Epoch 19/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0189 - mse: 1.0189 - val_loss: 0.9517 - val_mse: 0.9517
# Epoch 20/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0208 - mse: 1.0208 - val_loss: 0.9725 - val_mse: 0.9725
# Epoch 21/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0189 - mse: 1.0189 - val_loss: 1.1230 - val_mse: 1.1230
# Epoch 22/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0198 - mse: 1.0198 - val_loss: 0.9404 - val_mse: 0.9404
# Epoch 23/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0164 - mse: 1.0164 - val_loss: 1.0412 - val_mse: 1.0412
# Epoch 24/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0160 - mse: 1.0160 - val_loss: 0.9482 - val_mse: 0.9482
# Epoch 25/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0196 - mse: 1.0196 - val_loss: 0.9739 - val_mse: 0.9739
# Epoch 26/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0166 - mse: 1.0166 - val_loss: 0.9993 - val_mse: 0.9993
# Epoch 27/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0148 - mse: 1.0148 - val_loss: 0.9407 - val_mse: 0.9407
# Epoch 28/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0184 - mse: 1.0184 - val_loss: 0.9354 - val_mse: 0.9354
# Epoch 29/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0179 - mse: 1.0179 - val_loss: 0.9378 - val_mse: 0.9378
# Epoch 30/30
# 134/134 [==============================] - 0s 2ms/step - loss: 1.0167 - mse: 1.0167 - val_loss: 1.0001 - val_mse: 1.0001

# %%
def plot_models(models):
    for i in range(len(models)):
        print(f'{mod_names[i]}')
        plot_perf(models[i], y_target, x_valid, y_valid,150)

        # look into training history
        # Plot training & validation loss values
        plt. subplots(figsize=(15,5))
        plt.subplot(1,2,1)
        plt.plot(histo[i].history['loss'])
        plt.plot(histo[i].history['val_loss'])
        plt.title('Model loss', fontsize=16)
        plt.grid()
        plt.ylabel('Loss')
        plt.xlabel('Epochs')
        plt.legend(['Train', 'Validation'], loc='best')

        # Plot target and fit
        plt.subplot(1,2,2)
        plt.title('Target function and predicted function', fontsize=16)
        x_predicted = np.random.uniform(-1, 1, 100)
        y_predicted = models[i].predict(x_predicted)
        # Fitted function
        plt.plot(x_predicted, y_predicted,'ro', label='predicted')
        # Target function
        plt.plot(x_valid, y_target, label='target')
        plt.legend()
        plt.grid(True)
        plt.show()
plot_models(models)
# Out:
# MORE NODE
#
#
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0400 - mse: 0.0400
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.04003208130598068
# Test accuracy: 0.04003208130598068
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 3ms/step
# MORE LAYER
#
#
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3430 - mse: 0.3430
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.34300869703292847
# Test accuracy: 0.34300869703292847
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 4ms/step
# MORE NODE & LAYER
#
#
# ------------------------------------------------------
#
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0114 - mse: 0.0114
#
# Evaluation of the model by comparison with the exact curve:
# Test loss: 0.011424963362514973
# Test accuracy: 0.011424963362514973
#
#
# ------------------------------------------------------
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# Now try varying some activations functions to see which one is the most optimizing

# %%
activations =["selu","relu","gelu","sigmoid","softmax","linear"]
multimodels = []
multihistory = []
for activation in activations:
    #setting model
    multimodels.append(Set_model(n_layer, n_node, activation))

    #compiling
    Compile(models, SGD(),'mse','mse',mod_names)

    #starting model
    multihistory.append(History(models,n_epochs,mod_names))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 15)                30
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
#  dense_5 (Dense)             (None, 1)                 2
#
#  dense_6 (Dense)             (None, 1)                 2
#
#  dense_7 (Dense)             (None, 1)                 2
#
#  dense_8 (Dense)             (None, 1)                 2
#
#  dense_9 (Dense)             (None, 1)                 2
#
#  dense_10 (Dense)            (None, 1)                 2
#
#  dense_11 (Dense)            (None, 1)                 2
#
#  dense_12 (Dense)            (None, 1)                 2
#
#  dense_13 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1)                 2
#
#  dense_15 (Dense)            (None, 2)                 4
#
#  dense_16 (Dense)            (None, 3)                 9
#
#  dense_17 (Dense)            (None, 4)                 16
#
#  dense_18 (Dense)            (None, 3)                 15
#
#  dense_19 (Dense)            (None, 2)                 8
#
#  dense_20 (Dense)            (None, 1)                 3
#
#  dense_21 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0549 - mse: 1.0549 - val_loss: 0.9471 - val_mse: 0.9471
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0491 - mse: 1.0491 - val_loss: 0.9272 - val_mse: 0.9272
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0479 - mse: 1.0479 - val_loss: 0.9164 - val_mse: 0.9164
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0427 - mse: 1.0427 - val_loss: 0.9187 - val_mse: 0.9187
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0418 - mse: 1.0418 - val_loss: 0.9152 - val_mse: 0.9152
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0397 - mse: 1.0397 - val_loss: 0.9071 - val_mse: 0.9071
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0388 - mse: 1.0388 - val_loss: 0.9035 - val_mse: 0.9035
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0359 - mse: 1.0359 - val_loss: 0.8928 - val_mse: 0.8928
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0338 - mse: 1.0338 - val_loss: 0.8838 - val_mse: 0.8838
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0337 - mse: 1.0337 - val_loss: 0.8944 - val_mse: 0.8944
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0303 - mse: 1.0303 - val_loss: 0.9011 - val_mse: 0.9011
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0298 - mse: 1.0298 - val_loss: 0.9163 - val_mse: 0.9163
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0291 - mse: 1.0291 - val_loss: 0.9048 - val_mse: 0.9048
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0253 - mse: 1.0253 - val_loss: 0.9260 - val_mse: 0.9260
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0262 - mse: 1.0262 - val_loss: 0.8937 - val_mse: 0.8937
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0261 - mse: 1.0261 - val_loss: 0.9026 - val_mse: 0.9026
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0265 - mse: 1.0265 - val_loss: 0.9085 - val_mse: 0.9085
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0233 - mse: 1.0233 - val_loss: 0.8935 - val_mse: 0.8935
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0236 - mse: 1.0236 - val_loss: 0.9087 - val_mse: 0.9087
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0239 - mse: 1.0239 - val_loss: 0.8921 - val_mse: 0.8921
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0258 - mse: 1.0258 - val_loss: 0.8870 - val_mse: 0.8870
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0230 - mse: 1.0230 - val_loss: 0.8796 - val_mse: 0.8796
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0216 - mse: 1.0216 - val_loss: 0.9173 - val_mse: 0.9173
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0226 - mse: 1.0226 - val_loss: 0.9040 - val_mse: 0.9040
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0241 - mse: 1.0241 - val_loss: 0.9012 - val_mse: 0.9012
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0230 - mse: 1.0230 - val_loss: 0.8797 - val_mse: 0.8797
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0199 - mse: 1.0199 - val_loss: 0.9168 - val_mse: 0.9168
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0197 - mse: 1.0197 - val_loss: 0.9399 - val_mse: 0.9399
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0224 - mse: 1.0224 - val_loss: 0.8882 - val_mse: 0.8882
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0225 - mse: 1.0225 - val_loss: 0.8853 - val_mse: 0.8853
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.2711 - mse: 1.2711 - val_loss: 1.3057 - val_mse: 1.3057
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2685 - mse: 1.2685 - val_loss: 1.3132 - val_mse: 1.3132
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2685 - mse: 1.2685 - val_loss: 1.3015 - val_mse: 1.3015
# Epoch 4/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2670 - mse: 1.2670 - val_loss: 1.3088 - val_mse: 1.3088
# Epoch 5/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2658 - mse: 1.2658 - val_loss: 1.2983 - val_mse: 1.2983
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2683 - mse: 1.2683 - val_loss: 1.3210 - val_mse: 1.3210
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2668 - mse: 1.2668 - val_loss: 1.3051 - val_mse: 1.3051
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2656 - mse: 1.2656 - val_loss: 1.3058 - val_mse: 1.3058
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2660 - mse: 1.2660 - val_loss: 1.3034 - val_mse: 1.3034
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2639 - mse: 1.2639 - val_loss: 1.3022 - val_mse: 1.3022
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2639 - mse: 1.2639 - val_loss: 1.3409 - val_mse: 1.3409
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2643 - mse: 1.2643 - val_loss: 1.3289 - val_mse: 1.3289
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2621 - mse: 1.2621 - val_loss: 1.3286 - val_mse: 1.3286
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2639 - mse: 1.2639 - val_loss: 1.2948 - val_mse: 1.2948
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2634 - mse: 1.2634 - val_loss: 1.3398 - val_mse: 1.3398
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2618 - mse: 1.2618 - val_loss: 1.3213 - val_mse: 1.3213
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2615 - mse: 1.2615 - val_loss: 1.3027 - val_mse: 1.3027
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2601 - mse: 1.2601 - val_loss: 1.2959 - val_mse: 1.2959
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2575 - mse: 1.2575 - val_loss: 1.3401 - val_mse: 1.3401
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2588 - mse: 1.2588 - val_loss: 1.2895 - val_mse: 1.2895
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2598 - mse: 1.2598 - val_loss: 1.2992 - val_mse: 1.2992
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2580 - mse: 1.2580 - val_loss: 1.3159 - val_mse: 1.3159
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2585 - mse: 1.2585 - val_loss: 1.3120 - val_mse: 1.3120
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2589 - mse: 1.2589 - val_loss: 1.3004 - val_mse: 1.3004
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2581 - mse: 1.2581 - val_loss: 1.3301 - val_mse: 1.3301
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2580 - mse: 1.2580 - val_loss: 1.3004 - val_mse: 1.3004
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2587 - mse: 1.2587 - val_loss: 1.3094 - val_mse: 1.3094
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2578 - mse: 1.2578 - val_loss: 1.3218 - val_mse: 1.3218
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2599 - mse: 1.2599 - val_loss: 1.2798 - val_mse: 1.2798
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2591 - mse: 1.2591 - val_loss: 1.2891 - val_mse: 1.2891
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.0052 - mse: 1.0052 - val_loss: 0.9512 - val_mse: 0.9512
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0047 - mse: 1.0047 - val_loss: 0.9306 - val_mse: 0.9306
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0104 - mse: 1.0104 - val_loss: 0.9700 - val_mse: 0.9700
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0059 - mse: 1.0059 - val_loss: 1.0129 - val_mse: 1.0129
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0108 - mse: 1.0108 - val_loss: 0.9232 - val_mse: 0.9232
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0077 - mse: 1.0077 - val_loss: 0.9495 - val_mse: 0.9495
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0047 - mse: 1.0047 - val_loss: 0.9300 - val_mse: 0.9300
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9980 - mse: 0.9980 - val_loss: 0.9799 - val_mse: 0.9799
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0140 - mse: 1.0140 - val_loss: 0.9191 - val_mse: 0.9191
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9985 - mse: 0.9985 - val_loss: 0.9737 - val_mse: 0.9737
# Epoch 11/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0123 - mse: 1.0123 - val_loss: 0.9115 - val_mse: 0.9115
# Epoch 12/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0028 - mse: 1.0028 - val_loss: 0.9530 - val_mse: 0.9530
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0061 - mse: 1.0061 - val_loss: 0.9314 - val_mse: 0.9314
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0012 - mse: 1.0012 - val_loss: 1.0265 - val_mse: 1.0265
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0089 - mse: 1.0089 - val_loss: 0.9092 - val_mse: 0.9092
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0116 - mse: 1.0116 - val_loss: 0.9217 - val_mse: 0.9217
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0058 - mse: 1.0058 - val_loss: 0.9924 - val_mse: 0.9924
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0113 - mse: 1.0113 - val_loss: 0.9575 - val_mse: 0.9575
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0047 - mse: 1.0047 - val_loss: 0.9186 - val_mse: 0.9186
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0080 - mse: 1.0080 - val_loss: 0.9577 - val_mse: 0.9577
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0021 - mse: 1.0021 - val_loss: 0.9946 - val_mse: 0.9946
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0014 - mse: 1.0014 - val_loss: 1.0776 - val_mse: 1.0776
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0065 - mse: 1.0065 - val_loss: 0.9844 - val_mse: 0.9844
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0004 - mse: 1.0004 - val_loss: 0.9696 - val_mse: 0.9696
# Epoch 25/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0018 - mse: 1.0018 - val_loss: 0.9374 - val_mse: 0.9374
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0003 - mse: 1.0003 - val_loss: 0.9297 - val_mse: 0.9297
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0028 - mse: 1.0028 - val_loss: 0.9195 - val_mse: 0.9195
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0122 - mse: 1.0122 - val_loss: 0.9428 - val_mse: 0.9428
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0013 - mse: 1.0013 - val_loss: 0.9174 - val_mse: 0.9174
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0018 - mse: 1.0018 - val_loss: 0.9598 - val_mse: 0.9598
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 15)                30
#
#  dense_3 (Dense)             (None, 1)                 16
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
#  dense_5 (Dense)             (None, 1)                 2
#
#  dense_6 (Dense)             (None, 1)                 2
#
#  dense_7 (Dense)             (None, 1)                 2
#
#  dense_8 (Dense)             (None, 1)                 2
#
#  dense_9 (Dense)             (None, 1)                 2
#
#  dense_10 (Dense)            (None, 1)                 2
#
#  dense_11 (Dense)            (None, 1)                 2
#
#  dense_12 (Dense)            (None, 1)                 2
#
#  dense_13 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1)                 2
#
#  dense_15 (Dense)            (None, 2)                 4
#
#  dense_16 (Dense)            (None, 3)                 9
#
#  dense_17 (Dense)            (None, 4)                 16
#
#  dense_18 (Dense)            (None, 3)                 15
#
#  dense_19 (Dense)            (None, 2)                 8
#
#  dense_20 (Dense)            (None, 1)                 3
#
#  dense_21 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0195 - mse: 1.0195 - val_loss: 0.8820 - val_mse: 0.8820
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0210 - mse: 1.0210 - val_loss: 0.8865 - val_mse: 0.8865
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0184 - mse: 1.0184 - val_loss: 0.9026 - val_mse: 0.9026
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0192 - mse: 1.0192 - val_loss: 0.8948 - val_mse: 0.8948
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0202 - mse: 1.0202 - val_loss: 0.8994 - val_mse: 0.8994
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0195 - mse: 1.0195 - val_loss: 0.9002 - val_mse: 0.9002
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0175 - mse: 1.0175 - val_loss: 0.9307 - val_mse: 0.9307
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0186 - mse: 1.0186 - val_loss: 0.9020 - val_mse: 0.9020
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0169 - mse: 1.0169 - val_loss: 0.8921 - val_mse: 0.8921
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0179 - mse: 1.0179 - val_loss: 0.9356 - val_mse: 0.9356
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0191 - mse: 1.0191 - val_loss: 0.8861 - val_mse: 0.8861
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0173 - mse: 1.0173 - val_loss: 0.8862 - val_mse: 0.8862
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0175 - mse: 1.0175 - val_loss: 0.8952 - val_mse: 0.8952
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0172 - mse: 1.0172 - val_loss: 0.9010 - val_mse: 0.9010
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0158 - mse: 1.0158 - val_loss: 0.8827 - val_mse: 0.8827
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0178 - mse: 1.0178 - val_loss: 0.8972 - val_mse: 0.8972
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0167 - mse: 1.0167 - val_loss: 0.8892 - val_mse: 0.8892
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0162 - mse: 1.0162 - val_loss: 0.9101 - val_mse: 0.9101
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0150 - mse: 1.0150 - val_loss: 0.8834 - val_mse: 0.8834
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0160 - mse: 1.0160 - val_loss: 0.8983 - val_mse: 0.8983
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0144 - mse: 1.0144 - val_loss: 0.8896 - val_mse: 0.8896
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0151 - mse: 1.0151 - val_loss: 0.8863 - val_mse: 0.8863
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0141 - mse: 1.0141 - val_loss: 0.9016 - val_mse: 0.9016
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0126 - mse: 1.0126 - val_loss: 0.8843 - val_mse: 0.8843
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0146 - mse: 1.0146 - val_loss: 0.9429 - val_mse: 0.9429
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0134 - mse: 1.0134 - val_loss: 0.8852 - val_mse: 0.8852
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0134 - mse: 1.0134 - val_loss: 0.8981 - val_mse: 0.8981
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0119 - mse: 1.0119 - val_loss: 0.8893 - val_mse: 0.8893
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0122 - mse: 1.0122 - val_loss: 0.9060 - val_mse: 0.9060
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0134 - mse: 1.0134 - val_loss: 0.9155 - val_mse: 0.9155
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.2586 - mse: 1.2586 - val_loss: 1.2882 - val_mse: 1.2882
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2566 - mse: 1.2566 - val_loss: 1.2837 - val_mse: 1.2837
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2595 - mse: 1.2595 - val_loss: 1.3352 - val_mse: 1.3352
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2569 - mse: 1.2569 - val_loss: 1.2948 - val_mse: 1.2948
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2583 - mse: 1.2583 - val_loss: 1.3313 - val_mse: 1.3313
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2561 - mse: 1.2561 - val_loss: 1.3162 - val_mse: 1.3162
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2561 - mse: 1.2561 - val_loss: 1.2840 - val_mse: 1.2840
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2565 - mse: 1.2565 - val_loss: 1.3050 - val_mse: 1.3050
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2576 - mse: 1.2576 - val_loss: 1.2776 - val_mse: 1.2776
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2582 - mse: 1.2582 - val_loss: 1.3075 - val_mse: 1.3075
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2581 - mse: 1.2581 - val_loss: 1.2790 - val_mse: 1.2790
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2553 - mse: 1.2553 - val_loss: 1.2879 - val_mse: 1.2879
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2562 - mse: 1.2562 - val_loss: 1.2773 - val_mse: 1.2773
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2556 - mse: 1.2556 - val_loss: 1.2901 - val_mse: 1.2901
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2571 - mse: 1.2571 - val_loss: 1.3056 - val_mse: 1.3056
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2570 - mse: 1.2570 - val_loss: 1.2858 - val_mse: 1.2858
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2566 - mse: 1.2566 - val_loss: 1.2876 - val_mse: 1.2876
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2555 - mse: 1.2555 - val_loss: 1.3443 - val_mse: 1.3443
# Epoch 19/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2571 - mse: 1.2571 - val_loss: 1.2846 - val_mse: 1.2846
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2545 - mse: 1.2545 - val_loss: 1.2847 - val_mse: 1.2847
# Epoch 21/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2588 - mse: 1.2588 - val_loss: 1.2875 - val_mse: 1.2875
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2570 - mse: 1.2570 - val_loss: 1.2920 - val_mse: 1.2920
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2551 - mse: 1.2551 - val_loss: 1.3060 - val_mse: 1.3060
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2550 - mse: 1.2550 - val_loss: 1.2780 - val_mse: 1.2780
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2570 - mse: 1.2570 - val_loss: 1.2755 - val_mse: 1.2755
# Epoch 26/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2548 - mse: 1.2548 - val_loss: 1.3008 - val_mse: 1.3008
# Epoch 27/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2552 - mse: 1.2552 - val_loss: 1.2900 - val_mse: 1.2900
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2569 - mse: 1.2569 - val_loss: 1.2771 - val_mse: 1.2771
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2575 - mse: 1.2575 - val_loss: 1.3145 - val_mse: 1.3145
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2552 - mse: 1.2552 - val_loss: 1.3455 - val_mse: 1.3455
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.0013 - mse: 1.0013 - val_loss: 0.9963 - val_mse: 0.9963
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0034 - mse: 1.0034 - val_loss: 0.9410 - val_mse: 0.9410
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9945 - mse: 0.9945 - val_loss: 0.9648 - val_mse: 0.9648
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0064 - mse: 1.0064 - val_loss: 1.0046 - val_mse: 1.0046
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0005 - mse: 1.0005 - val_loss: 0.9321 - val_mse: 0.9321
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0004 - mse: 1.0004 - val_loss: 0.9447 - val_mse: 0.9447
# Epoch 7/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9990 - mse: 0.9990 - val_loss: 0.9479 - val_mse: 0.9479
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9984 - mse: 0.9984 - val_loss: 0.9732 - val_mse: 0.9732
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0040 - mse: 1.0040 - val_loss: 0.9399 - val_mse: 0.9399
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0016 - mse: 1.0016 - val_loss: 0.9124 - val_mse: 0.9124
# Epoch 11/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0036 - mse: 1.0036 - val_loss: 0.9179 - val_mse: 0.9179
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0005 - mse: 1.0005 - val_loss: 0.9102 - val_mse: 0.9102
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9987 - mse: 0.9987 - val_loss: 1.1328 - val_mse: 1.1328
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9976 - mse: 0.9976 - val_loss: 0.9757 - val_mse: 0.9757
# Epoch 15/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0029 - mse: 1.0029 - val_loss: 0.9204 - val_mse: 0.9204
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0032 - mse: 1.0032 - val_loss: 0.9836 - val_mse: 0.9836
# Epoch 17/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0034 - mse: 1.0034 - val_loss: 0.9097 - val_mse: 0.9097
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9976 - mse: 0.9976 - val_loss: 0.9388 - val_mse: 0.9388
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9995 - mse: 0.9995 - val_loss: 0.9239 - val_mse: 0.9239
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0003 - mse: 1.0003 - val_loss: 0.9678 - val_mse: 0.9678
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9948 - mse: 0.9948 - val_loss: 0.9192 - val_mse: 0.9192
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9985 - mse: 0.9985 - val_loss: 0.9452 - val_mse: 0.9452
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0009 - mse: 1.0009 - val_loss: 0.9653 - val_mse: 0.9653
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0007 - mse: 1.0007 - val_loss: 0.9199 - val_mse: 0.9199
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0016 - mse: 1.0016 - val_loss: 0.9572 - val_mse: 0.9572
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0064 - mse: 1.0064 - val_loss: 0.9267 - val_mse: 0.9267
# Epoch 27/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9991 - mse: 0.9991 - val_loss: 0.9243 - val_mse: 0.9243
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9994 - mse: 0.9994 - val_loss: 0.9199 - val_mse: 0.9199
# Epoch 29/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9957 - mse: 0.9957 - val_loss: 0.9890 - val_mse: 0.9890
# Epoch 30/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9997 - mse: 0.9997 - val_loss: 0.9750 - val_mse: 0.9750
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 15)                30
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
#  dense_5 (Dense)             (None, 1)                 2
#  dense_6 (Dense)             (None, 1)                 2
#
#  dense_7 (Dense)             (None, 1)                 2
#
#  dense_8 (Dense)             (None, 1)                 2
#
#  dense_9 (Dense)             (None, 1)                 2
#
#  dense_10 (Dense)            (None, 1)                 2
#
#  dense_11 (Dense)            (None, 1)                 2
#
#  dense_12 (Dense)            (None, 1)                 2
#
#  dense_13 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1)                 2
#
#  dense_15 (Dense)            (None, 2)                 4
#
#  dense_16 (Dense)            (None, 3)                 9
#
#  dense_17 (Dense)            (None, 4)                 16
#
#  dense_18 (Dense)            (None, 3)                 15
#
#  dense_19 (Dense)            (None, 2)                 8
#
#  dense_20 (Dense)            (None, 1)                 3
#
#  dense_21 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0135 - mse: 1.0135 - val_loss: 0.8930 - val_mse: 0.8930
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0120 - mse: 1.0120 - val_loss: 0.8912 - val_mse: 0.8912
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0125 - mse: 1.0125 - val_loss: 0.8923 - val_mse: 0.8923
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0120 - mse: 1.0120 - val_loss: 0.8804 - val_mse: 0.8804
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0103 - mse: 1.0103 - val_loss: 0.8839 - val_mse: 0.8839
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0111 - mse: 1.0111 - val_loss: 0.8958 - val_mse: 0.8958
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0098 - mse: 1.0098 - val_loss: 0.8934 - val_mse: 0.8934
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0113 - mse: 1.0113 - val_loss: 0.9016 - val_mse: 0.9016
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0103 - mse: 1.0103 - val_loss: 0.9447 - val_mse: 0.9447
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0096 - mse: 1.0096 - val_loss: 0.9045 - val_mse: 0.9045
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0114 - mse: 1.0114 - val_loss: 0.9028 - val_mse: 0.9028
# Epoch 12/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.0116 - mse: 1.0116 - val_loss: 0.9269 - val_mse: 0.9269
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0090 - mse: 1.0090 - val_loss: 0.9193 - val_mse: 0.9193
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0102 - mse: 1.0102 - val_loss: 0.8904 - val_mse: 0.8904
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0124 - mse: 1.0124 - val_loss: 0.9056 - val_mse: 0.9056
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0086 - mse: 1.0086 - val_loss: 0.9251 - val_mse: 0.9251
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0100 - mse: 1.0100 - val_loss: 0.8847 - val_mse: 0.8847
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0081 - mse: 1.0081 - val_loss: 0.9584 - val_mse: 0.9584
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0094 - mse: 1.0094 - val_loss: 0.9106 - val_mse: 0.9106
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0077 - mse: 1.0077 - val_loss: 0.9288 - val_mse: 0.9288
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0090 - mse: 1.0090 - val_loss: 0.9033 - val_mse: 0.9033
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0096 - mse: 1.0096 - val_loss: 0.9233 - val_mse: 0.9233
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0086 - mse: 1.0086 - val_loss: 0.9092 - val_mse: 0.9092
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0071 - mse: 1.0071 - val_loss: 0.8811 - val_mse: 0.8811
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0078 - mse: 1.0078 - val_loss: 0.9508 - val_mse: 0.9508
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0070 - mse: 1.0070 - val_loss: 0.8784 - val_mse: 0.8784
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0048 - mse: 1.0048 - val_loss: 0.8846 - val_mse: 0.8846
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0087 - mse: 1.0087 - val_loss: 0.8807 - val_mse: 0.8807
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0065 - mse: 1.0065 - val_loss: 0.8990 - val_mse: 0.8990
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0069 - mse: 1.0069 - val_loss: 0.8809 - val_mse: 0.8809
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.2584 - mse: 1.2584 - val_loss: 1.3025 - val_mse: 1.3025
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2557 - mse: 1.2557 - val_loss: 1.2818 - val_mse: 1.2818
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2547 - mse: 1.2547 - val_loss: 1.2757 - val_mse: 1.2757
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2552 - mse: 1.2552 - val_loss: 1.3132 - val_mse: 1.3132
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2562 - mse: 1.2562 - val_loss: 1.2951 - val_mse: 1.2951
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2564 - mse: 1.2564 - val_loss: 1.2856 - val_mse: 1.2856
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2549 - mse: 1.2549 - val_loss: 1.3083 - val_mse: 1.3083
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2550 - mse: 1.2550 - val_loss: 1.2915 - val_mse: 1.2915
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2540 - mse: 1.2540 - val_loss: 1.2970 - val_mse: 1.2970
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2558 - mse: 1.2558 - val_loss: 1.2716 - val_mse: 1.2716
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2566 - mse: 1.2566 - val_loss: 1.2792 - val_mse: 1.2792
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2564 - mse: 1.2564 - val_loss: 1.2785 - val_mse: 1.2785
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2558 - mse: 1.2558 - val_loss: 1.3478 - val_mse: 1.3478
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2578 - mse: 1.2578 - val_loss: 1.2734 - val_mse: 1.2734
# Epoch 15/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2519 - mse: 1.2519 - val_loss: 1.2867 - val_mse: 1.2867
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2554 - mse: 1.2554 - val_loss: 1.2975 - val_mse: 1.2975
# Epoch 17/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2553 - mse: 1.2553 - val_loss: 1.2965 - val_mse: 1.2965
# Epoch 18/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2534 - mse: 1.2534 - val_loss: 1.2789 - val_mse: 1.2789
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2554 - mse: 1.2554 - val_loss: 1.3022 - val_mse: 1.3022
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2547 - mse: 1.2547 - val_loss: 1.2751 - val_mse: 1.2751
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2531 - mse: 1.2531 - val_loss: 1.2832 - val_mse: 1.2832
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2536 - mse: 1.2536 - val_loss: 1.2731 - val_mse: 1.2731
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2548 - mse: 1.2548 - val_loss: 1.3188 - val_mse: 1.3188
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2552 - mse: 1.2552 - val_loss: 1.2692 - val_mse: 1.2692
# Epoch 25/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2584 - mse: 1.2584 - val_loss: 1.2922 - val_mse: 1.2922
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2550 - mse: 1.2550 - val_loss: 1.2881 - val_mse: 1.2881
# Epoch 27/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2584 - mse: 1.2584 - val_loss: 1.2774 - val_mse: 1.2774
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2539 - mse: 1.2539 - val_loss: 1.2882 - val_mse: 1.2882
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2554 - mse: 1.2554 - val_loss: 1.2757 - val_mse: 1.2757
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2566 - mse: 1.2566 - val_loss: 1.3360 - val_mse: 1.3360
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 0.9980 - mse: 0.9980 - val_loss: 0.9673 - val_mse: 0.9673
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9985 - mse: 0.9985 - val_loss: 0.9754 - val_mse: 0.9754
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0041 - mse: 1.0041 - val_loss: 0.9415 - val_mse: 0.9415
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0002 - mse: 1.0002 - val_loss: 0.9225 - val_mse: 0.9225
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0052 - mse: 1.0052 - val_loss: 0.9927 - val_mse: 0.9927
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9986 - mse: 0.9986 - val_loss: 0.9311 - val_mse: 0.9311
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0017 - mse: 1.0017 - val_loss: 0.9354 - val_mse: 0.9354
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9946 - mse: 0.9946 - val_loss: 0.9585 - val_mse: 0.9585
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9991 - mse: 0.9991 - val_loss: 0.9284 - val_mse: 0.9284
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9963 - mse: 0.9963 - val_loss: 0.9992 - val_mse: 0.9992
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0016 - mse: 1.0016 - val_loss: 0.9158 - val_mse: 0.9158
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9976 - mse: 0.9976 - val_loss: 0.9353 - val_mse: 0.9353
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9938 - mse: 0.9938 - val_loss: 0.9387 - val_mse: 0.9387
# Epoch 14/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9996 - mse: 0.9996 - val_loss: 0.9407 - val_mse: 0.9407
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9990 - mse: 0.9990 - val_loss: 0.9543 - val_mse: 0.9543
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9994 - mse: 0.9994 - val_loss: 1.0272 - val_mse: 1.0272
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9982 - mse: 0.9982 - val_loss: 0.9683 - val_mse: 0.9683
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9989 - mse: 0.9989 - val_loss: 0.9782 - val_mse: 0.9782
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9991 - mse: 0.9991 - val_loss: 0.9342 - val_mse: 0.9342
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9972 - mse: 0.9972 - val_loss: 0.9380 - val_mse: 0.9380
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9975 - mse: 0.9975 - val_loss: 0.9344 - val_mse: 0.9344
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9312 - val_mse: 0.9312
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9962 - mse: 0.9962 - val_loss: 0.9220 - val_mse: 0.9220
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0030 - mse: 1.0030 - val_loss: 0.9375 - val_mse: 0.9375
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9966 - mse: 0.9966 - val_loss: 0.9415 - val_mse: 0.9415
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9950 - mse: 0.9950 - val_loss: 1.0173 - val_mse: 1.0173
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9986 - mse: 0.9986 - val_loss: 0.9751 - val_mse: 0.9751
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9963 - mse: 0.9963 - val_loss: 0.9112 - val_mse: 0.9112
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.0016 - mse: 1.0016 - val_loss: 0.9350 - val_mse: 0.9350
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9988 - mse: 0.9988 - val_loss: 0.9527 - val_mse: 0.9527
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 15)                30
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# ...
# Epoch 29/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9983 - mse: 0.9983 - val_loss: 0.9411 - val_mse: 0.9411
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9932 - mse: 0.9932 - val_loss: 0.9412 - val_mse: 0.9412
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 15)                30
#
#  dense_3 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 48
# Trainable params: 48
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1)                 2
#
#  dense_5 (Dense)             (None, 1)                 2
#
#  dense_6 (Dense)             (None, 1)                 2
#
#  dense_7 (Dense)             (None, 1)                 2
#
#  dense_8 (Dense)             (None, 1)                 2
#
#  dense_9 (Dense)             (None, 1)                 2
#
#  dense_10 (Dense)            (None, 1)                 2
#
#  dense_11 (Dense)            (None, 1)                 2
#
#  dense_12 (Dense)            (None, 1)                 2
#
#  dense_13 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 20
# Trainable params: 20
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1)                 2
#
#  dense_15 (Dense)            (None, 2)                 4
#
#  dense_16 (Dense)            (None, 3)                 9
#
#  dense_17 (Dense)            (None, 4)                 16
#  dense_18 (Dense)            (None, 3)                 15
#
#  dense_19 (Dense)            (None, 2)                 8
#
#  dense_20 (Dense)            (None, 1)                 3
#
#  dense_21 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 59
# Trainable params: 59
# Non-trainable params: 0
# _________________________________________________________________
#
# Epoch 1/30
# 67/67 [==============================] - 1s 3ms/step - loss: 0.9953 - mse: 0.9953 - val_loss: 0.9115 - val_mse: 0.9115
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9976 - mse: 0.9976 - val_loss: 0.9345 - val_mse: 0.9345
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9983 - mse: 0.9983 - val_loss: 0.9020 - val_mse: 0.9020
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9968 - mse: 0.9968 - val_loss: 0.9090 - val_mse: 0.9090
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9958 - mse: 0.9958 - val_loss: 0.8947 - val_mse: 0.8947
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9969 - mse: 0.9969 - val_loss: 0.9365 - val_mse: 0.9365
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9949 - mse: 0.9949 - val_loss: 0.9020 - val_mse: 0.9020
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9968 - mse: 0.9968 - val_loss: 0.9193 - val_mse: 0.9193
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9957 - mse: 0.9957 - val_loss: 0.9242 - val_mse: 0.9242
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9965 - mse: 0.9965 - val_loss: 0.9784 - val_mse: 0.9784
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9944 - mse: 0.9944 - val_loss: 0.9007 - val_mse: 0.9007
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9978 - mse: 0.9978 - val_loss: 0.9085 - val_mse: 0.9085
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9947 - mse: 0.9947 - val_loss: 0.8931 - val_mse: 0.8931
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9983 - mse: 0.9983 - val_loss: 0.9087 - val_mse: 0.9087
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9972 - mse: 0.9972 - val_loss: 0.8946 - val_mse: 0.8946
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9988 - mse: 0.9988 - val_loss: 0.9105 - val_mse: 0.9105
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9966 - mse: 0.9966 - val_loss: 0.9191 - val_mse: 0.9191
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9948 - mse: 0.9948 - val_loss: 0.9282 - val_mse: 0.9282
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9960 - mse: 0.9960 - val_loss: 0.9054 - val_mse: 0.9054
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9958 - mse: 0.9958 - val_loss: 0.9450 - val_mse: 0.9450
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9941 - mse: 0.9941 - val_loss: 0.9248 - val_mse: 0.9248
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9949 - mse: 0.9949 - val_loss: 0.8885 - val_mse: 0.8885
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9952 - mse: 0.9952 - val_loss: 0.9207 - val_mse: 0.9207
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9952 - mse: 0.9952 - val_loss: 0.9115 - val_mse: 0.9115
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9946 - mse: 0.9946 - val_loss: 0.9388 - val_mse: 0.9388
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9990 - mse: 0.9990 - val_loss: 0.9011 - val_mse: 0.9011
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9982 - mse: 0.9982 - val_loss: 0.9062 - val_mse: 0.9062
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9953 - mse: 0.9953 - val_loss: 0.9239 - val_mse: 0.9239
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9958 - mse: 0.9958 - val_loss: 0.8885 - val_mse: 0.8885
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9967 - mse: 0.9967 - val_loss: 0.9426 - val_mse: 0.9426
# Epoch 1/30
# 67/67 [==============================] - 1s 4ms/step - loss: 1.2554 - mse: 1.2554 - val_loss: 1.2850 - val_mse: 1.2850
# Epoch 2/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2594 - mse: 1.2594 - val_loss: 1.2966 - val_mse: 1.2966
# Epoch 3/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2526 - mse: 1.2526 - val_loss: 1.2945 - val_mse: 1.2945
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2543 - mse: 1.2543 - val_loss: 1.2784 - val_mse: 1.2784
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2521 - mse: 1.2521 - val_loss: 1.2992 - val_mse: 1.2992
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2532 - mse: 1.2532 - val_loss: 1.2967 - val_mse: 1.2967
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2549 - mse: 1.2549 - val_loss: 1.2899 - val_mse: 1.2899
# Epoch 8/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2556 - mse: 1.2556 - val_loss: 1.2990 - val_mse: 1.2990
# Epoch 9/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2528 - mse: 1.2528 - val_loss: 1.2897 - val_mse: 1.2897
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2539 - mse: 1.2539 - val_loss: 1.2779 - val_mse: 1.2779
# Epoch 11/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2551 - mse: 1.2551 - val_loss: 1.2970 - val_mse: 1.2970
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2568 - mse: 1.2568 - val_loss: 1.2922 - val_mse: 1.2922
# Epoch 13/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2529 - mse: 1.2529 - val_loss: 1.2828 - val_mse: 1.2828
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2539 - mse: 1.2539 - val_loss: 1.2708 - val_mse: 1.2708
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2540 - mse: 1.2540 - val_loss: 1.2864 - val_mse: 1.2864
# Epoch 16/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2544 - mse: 1.2544 - val_loss: 1.3138 - val_mse: 1.3138
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2562 - mse: 1.2562 - val_loss: 1.2820 - val_mse: 1.2820
# Epoch 18/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2556 - mse: 1.2556 - val_loss: 1.3316 - val_mse: 1.3316
# Epoch 19/30
# 67/67 [==============================] - 0s 3ms/step - loss: 1.2545 - mse: 1.2545 - val_loss: 1.3101 - val_mse: 1.3101
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2528 - mse: 1.2528 - val_loss: 1.3171 - val_mse: 1.3171
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2555 - mse: 1.2555 - val_loss: 1.2706 - val_mse: 1.2706
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2555 - mse: 1.2555 - val_loss: 1.2776 - val_mse: 1.2776
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2532 - mse: 1.2532 - val_loss: 1.3260 - val_mse: 1.3260
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2533 - mse: 1.2533 - val_loss: 1.2840 - val_mse: 1.2840
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2553 - mse: 1.2553 - val_loss: 1.2723 - val_mse: 1.2723
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2535 - mse: 1.2535 - val_loss: 1.2658 - val_mse: 1.2658
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2546 - mse: 1.2546 - val_loss: 1.2888 - val_mse: 1.2888
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2543 - mse: 1.2543 - val_loss: 1.2971 - val_mse: 1.2971
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2523 - mse: 1.2523 - val_loss: 1.2881 - val_mse: 1.2881
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 1.2556 - mse: 1.2556 - val_loss: 1.2826 - val_mse: 1.2826
# Epoch 1/30
# 67/67 [==============================] - 1s 3ms/step - loss: 0.9972 - mse: 0.9972 - val_loss: 1.0068 - val_mse: 1.0068
# Epoch 2/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9980 - mse: 0.9980 - val_loss: 1.0176 - val_mse: 1.0176
# Epoch 3/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9984 - mse: 0.9984 - val_loss: 0.9336 - val_mse: 0.9336
# Epoch 4/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9915 - mse: 0.9915 - val_loss: 0.9381 - val_mse: 0.9381
# Epoch 5/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9954 - mse: 0.9954 - val_loss: 0.9113 - val_mse: 0.9113
# Epoch 6/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9948 - mse: 0.9948 - val_loss: 0.9160 - val_mse: 0.9160
# Epoch 7/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9945 - mse: 0.9945 - val_loss: 0.9349 - val_mse: 0.9349
# Epoch 8/30
# 67/67 [==============================] - 0s 3ms/step - loss: 0.9969 - mse: 0.9969 - val_loss: 0.9296 - val_mse: 0.9296
# Epoch 9/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9970 - mse: 0.9970 - val_loss: 0.9663 - val_mse: 0.9663
# Epoch 10/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9943 - mse: 0.9943 - val_loss: 0.9361 - val_mse: 0.9361
# Epoch 11/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9969 - mse: 0.9969 - val_loss: 0.9198 - val_mse: 0.9198
# Epoch 12/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9986 - mse: 0.9986 - val_loss: 0.9512 - val_mse: 0.9512
# Epoch 13/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9968 - mse: 0.9968 - val_loss: 0.9384 - val_mse: 0.9384
# Epoch 14/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9936 - mse: 0.9936 - val_loss: 0.9196 - val_mse: 0.9196
# Epoch 15/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9920 - mse: 0.9920 - val_loss: 0.9608 - val_mse: 0.9608
# Epoch 16/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9300 - val_mse: 0.9300
# Epoch 17/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9961 - mse: 0.9961 - val_loss: 0.9294 - val_mse: 0.9294
# Epoch 18/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9942 - mse: 0.9942 - val_loss: 0.9170 - val_mse: 0.9170
# Epoch 19/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9955 - mse: 0.9955 - val_loss: 0.9389 - val_mse: 0.9389
# Epoch 20/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9966 - mse: 0.9966 - val_loss: 0.9262 - val_mse: 0.9262
# Epoch 21/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9064 - val_mse: 0.9064
# Epoch 22/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9918 - mse: 0.9918 - val_loss: 0.9925 - val_mse: 0.9925
# Epoch 23/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9926 - mse: 0.9926 - val_loss: 0.9639 - val_mse: 0.9639
# Epoch 24/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9945 - mse: 0.9945 - val_loss: 0.9102 - val_mse: 0.9102
# Epoch 25/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9955 - mse: 0.9955 - val_loss: 0.9500 - val_mse: 0.9500
# Epoch 26/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9978 - mse: 0.9978 - val_loss: 0.9744 - val_mse: 0.9744
# Epoch 27/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9939 - mse: 0.9939 - val_loss: 0.9384 - val_mse: 0.9384
# Epoch 28/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9927 - mse: 0.9927 - val_loss: 0.9302 - val_mse: 0.9302
# Epoch 29/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9933 - mse: 0.9933 - val_loss: 0.9479 - val_mse: 0.9479
# Epoch 30/30
# 67/67 [==============================] - 0s 2ms/step - loss: 0.9989 - mse: 0.9989 - val_loss: 0.9236 - val_mse: 0.9236

# %%
def fit(model, x_valid, y_target,title_activation):
    plt.figure(figsize=(15,6))
    for lim in range(2):
        plt.subplot(1,2,lim+1)
        x_pred = np.random.uniform(-lim-1, lim+1, 200)
        plt.plot(x_valid, y_target)
        y_pred=model.predict(x_pred)
        plt.scatter(x_pred,y_pred,marker='.',label=mod_names[i])

        if(lim==0):
            plt.xlim(-1.1,1.1)
            plt.ylim(1,5)
        plt.legend(loc='best')
        plt.grid(True)
        if(lim==0): plt.title('inside training range')
        else: plt.title('outside training range')
    plt.suptitle(f"Models prediction with {title_activation} activation")
    plt.show()

# %%
multimodels.append(models)
i = 0
for mod in multimodels: 
    fit(mod,x_valid,y_target,activation[i])
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_62804/1829634305.py in <module>
#       2 i = 0
#       3 for mod in multimodels:
# ----> 4     fit(mod,x_valid,y_target,activation[i])
#       5     i=i+1
#
# /tmp/ipykernel_62804/1679571966.py in fit(model, x_valid, y_target, title_activation)
#       5         x_pred = np.random.uniform(-lim-1, lim+1, 200)
#       6         plt.plot(x_valid, y_target)
# ----> 7         y_pred=model.predict(x_pred)
#       8         plt.scatter(x_pred,y_pred,marker='.',label=mod_names[i])
#       9
#
# AttributeError: 'list' object has no attribute 'predict'

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>
