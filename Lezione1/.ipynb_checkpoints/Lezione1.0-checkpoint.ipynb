# %% [markdown]
# # <span style="color:red"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue"> Esercitazione 1 </span>

# %% [markdown]
# Test the Pseudo-Random Number generator by estimating the integer: $\langle r \rangle = \int_0^1 r dr$. Compute average and Standard deviation with a large number of throws, $M$, as a function of the number of blocks, $N$. This statistic instrument spoil Central Limit theorem.

# %% [markdown]
# es 1.1: First plot show $\langle r \rangle$ and its Standard Deviation of the mean as a function of the number of blocks, $N$</font>.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

M=100000
N=100
sum_prog, err_prog = np.loadtxt("../dati/dati1/dati1.1.1.dat", usecols=(0,1), delimiter=',', unpack='true')

x = np.arange(100)*M/N

plt.errorbar(x,sum_prog-0.5,yerr=err_prog)
plt.xlabel('#throws')
plt.ylabel('Media-Teoria')
plt.grid(True)
plt.show()

# %% [markdown]
# es 1.2: The second picture show the estimation of $\sigma^2$ and its uncertainty given by $\sigma^2 = \int_0^1 (r-1/2)^2 dr = 1/12$.

# %%
M=100000
N=100
sum_prog, err_prog = np.loadtxt("../dati/dati1/dati1.1.2.dat", usecols=(0,1), delimiter=',', unpack='true')

x = np.arange(100)*M/N

plt.errorbar(x,sum_prog-1/12,yerr=err_prog)
plt.xlabel('#throws')
plt.ylabel('<(r-0.5)^2>-1/12')
plt.grid(True)
plt.show()

# %% [markdown]
# es 1.1.3: Test about pseudo-random uniform distribution of the Pseudo-Random Number generator . Compute 100 values of $\chi^2$:
#
# $$\chi^2 = \sum_{i} \frac{\left( O_i - E_i \right)^2}{E_i}$$

# %%
chi_prog = np.loadtxt("../dati/dati1/dati1.1.3.dat", usecols=(0), delimiter=',', unpack='true')

# the histogram of the data
n_bins = 50
#chi_pro-g, bins, patches = plt.hist(chi_prog, n_bins, density=True)
plt.plot(chi_prog)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of chi quadro')
plt.grid(True)

plt.show()

# %%
date = np.loadtxt("../dati/dati1/dati1.2.1.dat", usecols=(0,1,2,3), delimiter=',', unpack='false')

# the histogram of the data

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of GAUSSIANA')
plt.grid(True)
n_bins = 100

chi_prog, bins, patches = plt.hist(date[0], n_bins, density=True)
plt.figure()

chi_prog, bins, patches = plt.hist(date[1], n_bins, density=True)
plt.figure()
n_bins = 100

chi_prog, bins, patches = plt.hist(date[2], n_bins, density=True)
plt.figure()
n_bins = 50

chi_prog, bins, patches = plt.hist(date[3], n_bins, density=True)
plt.figure()
plt.show()

# %%
date = np.loadtxt("../dati/dati1/dati1.2.2.dat", usecols=(0,1,2,3), delimiter=',', unpack='true')
# the histogram of the data
fig, axs = plt.subplots(2, 2)
fig.figsize=(12,12)
n_bins = 100
fig.tight_layout()
plt.grid(True)
axs[0, 0].hist(date[0], n_bins, density=True)
axs[0, 0].set_title('Time 1')
axs[0, 1].hist(date[1], n_bins, density=True)
axs[0, 1].set_title('Time 2')
axs[1, 0].hist(date[2], n_bins, density=True)
axs[1, 0].set_title('Time 3')
axs[1, 1].hist(date[3], n_bins, density=True)
axs[1, 1].set_title('Time 4')


for ax in axs.flat:
    ax.set(xlabel='# throws', ylabel='distribution')
    

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
date = np.loadtxt("../dati/dati1/dati1.2.3.dat", usecols=(0,1,2,3), delimiter=',', unpack='True')
print(date[0])
# the histogram of the data
n_bins = 10000
b = 10
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of LORENTZIANA')
plt.grid(True)

plt.xlim(-b,b)
plt.hist(date[0], n_bins, density=True)
plt.figure()
plt.xlim(-b,b)
plt.hist(date[1], n_bins, density=True)
plt.figure()

plt.xlim(-b,b)
plt.hist(date[2], n_bins, density=True)
plt.figure()

plt.xlim(-b,b)
plt.hist(date[3], n_bins, density=True)
plt.figure()

plt.show()
# Out:
# [ 0.02662682  1.05364418 -1.38625801 ...  0.39981282  0.
#  -0.57353735]

# %%
N=100
sum_prog, err_prog = np.loadtxt("../dati/dati1/dati1.3.dat", usecols=(0,1), delimiter=',', unpack='true')

x = np.arange(100)*M/N

plt.errorbar(x,sum_prog,yerr=err_prog)
plt.xlabel('#throws')
plt.ylabel('PI')
plt.grid(True)
plt.show()
